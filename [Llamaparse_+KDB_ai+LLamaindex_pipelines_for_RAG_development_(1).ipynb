# %% [markdown]
# <a href="https://colab.research.google.com/github/tokyo8182/LLM-RAG/blob/main/%5BLlamaparse_%2BKDB_ai%2BLLamaindex_pipelines_for_RAG_development_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # https://docs.llamaindex.ai/en/stable/module_guides/loading/ingestion_pipeline/
# https://docs.llamaindex.ai/en/stable/module_guides/loading/node_parsers/
# https://docs.llamaindex.ai/en/stable/module_guides/loading/node_parsers/modules/

# %% [markdown]
# To create a robust ingestion pipeline using the `IngestionPipeline` from `llama_index`, we will combine various transformations, document management, and async support to handle document ingestion, processing, and storage efficiently. Below, I’ll walk you through the key elements and how you can implement them in your ingestion pipeline, including handling vector databases, caching, parallel processing, and async support.
#
# ### Key Concepts in the Ingestion Pipeline:
#
# 1. **Transformations**: These are applied to your input documents. Each transformation processes the document and returns nodes (processed chunks). Common transformations include `SentenceSplitter`, `TitleExtractor`, and embeddings like `OpenAIEmbedding`.
#
# 2. **Document Management**: This feature ensures that duplicate documents are identified and reprocessed only if needed, based on their hash and `doc_id`. This is especially useful in data pipelines that ingest new documents regularly.
#
# 3. **Caching**: The pipeline supports caching of nodes and transformations. This helps speed up processing by reusing previously processed data when the same data and transformations are encountered.
#
# 4. **Vector Databases**: Ingestion pipelines can directly connect to vector stores like Qdrant, Redis, or other backends, enabling real-time indexing and search.
#
# 5. **Parallel Processing**: The pipeline can process documents in parallel by utilizing `num_workers`, which distributes tasks across multiple processors.
#
# 6. **Async Support**: The `IngestionPipeline` supports asynchronous operations, enabling batch processing of documents asynchronously for improved performance.
#
# ### Full Example Walkthrough:
#
# #### 1. **Basic Setup of Ingestion Pipeline:**
#
# Here, we define the transformations and create the pipeline.
#
# ```python
# from llama_index.core import Document
# from llama_index.embeddings.openai import OpenAIEmbedding
# from llama_index.core.node_parser import SentenceSplitter
# from llama_index.core.extractors import TitleExtractor
# from llama_index.core.ingestion import IngestionPipeline, IngestionCache
# from llama_index.vector_stores.qdrant import QdrantVectorStore
#
# import qdrant_client
#
# # Initialize the Qdrant client and vector store
# client = qdrant_client.QdrantClient(location=":memory:")
# vector_store = QdrantVectorStore(client=client, collection_name="test_store")
#
# # Create the pipeline with transformations
# pipeline = IngestionPipeline(
#     transformations=[
#         SentenceSplitter(chunk_size=25, chunk_overlap=0),  # Split the document into smaller chunks
#         TitleExtractor(),  # Extract the document title
#         OpenAIEmbedding(),  # Apply OpenAI embeddings to document chunks
#     ],
#     vector_store=vector_store  # Optionally, store results in a vector store
# )
#
# # Run the pipeline on a list of documents (in this case, just an example document)
# documents = [Document.example()]
# pipeline.run(documents=documents)
# ```
#
# In this example, the documents are split into smaller chunks, titles are extracted, and OpenAI embeddings are applied. These nodes are then inserted into the `Qdrant` vector store.
#
# #### 2. **Connecting to a Vector Database**:
#
# The `IngestionPipeline` can automatically insert nodes into a vector database. Here’s how you connect to the Qdrant vector store:
#
# ```python
# # Connect to Qdrant and initialize the vector store
# client = qdrant_client.QdrantClient(location=":memory:")
# vector_store = QdrantVectorStore(client=client, collection_name="documents_collection")
#
# # Create a pipeline that uses the vector store
# pipeline = IngestionPipeline(
#     transformations=[
#         SentenceSplitter(chunk_size=25, chunk_overlap=0),
#         TitleExtractor(),
#         OpenAIEmbedding(),
#     ],
#     vector_store=vector_store,
# )
#
# # Run the pipeline
# pipeline.run(documents=documents)
# ```
#
# After processing, the resulting nodes are inserted into the Qdrant vector store, making them available for later search or retrieval.
#
# #### 3. **Caching**:
#
# To avoid redundant computation, you can persist the cache. This is useful for improving performance when running the pipeline multiple times with the same data.
#
# ```python
# # Save the cache
# pipeline.persist("./pipeline_storage")
#
# # Load the cache and restore the pipeline state
# new_pipeline = IngestionPipeline(
#     transformations=[
#         SentenceSplitter(chunk_size=25, chunk_overlap=0),
#         TitleExtractor(),
#     ],
# )
# new_pipeline.load("./pipeline_storage")
#
# # Running the pipeline now will be faster due to the cache
# nodes = new_pipeline.run(documents=documents)
# ```
#
# This method ensures that the transformations are cached, and you don't need to repeat the work for the same data.
#
# #### 4. **Async Support**:
#
# If you have many documents to process, using the async functionality can greatly improve performance by processing multiple documents concurrently.
#
# ```python
# # Asynchronous document processing
# nodes = await pipeline.arun(documents=documents)
# ```
#
# This method allows the ingestion pipeline to process documents asynchronously, making it ideal for large-scale document ingestion tasks.
#
# #### 5. **Parallel Processing**:
#
# To further speed up processing, you can run the pipeline with multiple processes. This is useful when dealing with large datasets and want to utilize multiple CPU cores.
#
# ```python
# # Run the pipeline with parallel processing using multiprocessing
# pipeline.run(documents=documents, num_workers=4)
# ```
#
# The `num_workers` parameter controls how many processes to use for parallel processing. This ensures that the document processing is distributed across multiple cores.
#
# #### 6. **Document Management**:
#
# To manage document versions and ensure that duplicate documents are not processed unnecessarily, you can use a document store. Here, we use `SimpleDocumentStore` for this purpose:
#
# ```python
# from llama_index.core.storage.docstore import SimpleDocumentStore
#
# # Initialize the document store
# docstore = SimpleDocumentStore()
#
# # Create a pipeline that uses the document store
# pipeline = IngestionPipeline(
#     transformations=[
#         SentenceSplitter(chunk_size=25, chunk_overlap=0),
#         TitleExtractor(),
#         OpenAIEmbedding(),
#     ],
#     docstore=docstore,
# )
#
# # Run the pipeline
# pipeline.run(documents=documents)
# ```
#
# The `docstore` ensures that documents are checked for duplicates based on their hash and `doc_id`. If a document is already processed and stored, it will be skipped unless its content has changed.
#
# ### Complete Pipeline Example:
#
# ```python
# import asyncio
# from llama_index.core import Document
# from llama_index.embeddings.openai import OpenAIEmbedding
# from llama_index.core.node_parser import SentenceSplitter
# from llama_index.core.extractors import TitleExtractor
# from llama_index.core.ingestion import IngestionPipeline
# from llama_index.vector_stores.qdrant import QdrantVectorStore
# import qdrant_client
#
# # Define the async processing pipeline
# async def async_pipeline(documents):
#     client = qdrant_client.QdrantClient(location=":memory:")
#     vector_store = QdrantVectorStore(client=client, collection_name="test_collection")
#
#     pipeline = IngestionPipeline(
#         transformations=[
#             SentenceSplitter(chunk_size=25, chunk_overlap=0),
#             TitleExtractor(),
#             OpenAIEmbedding(),
#         ],
#         vector_store=vector_store
#     )
#
#     # Run the pipeline asynchronously
#     nodes = await pipeline.arun(documents=documents)
#     return nodes
#
# # Example document list
# documents = [Document.example()]
#
# # Run the pipeline and await the result
# result = asyncio.run(async_pipeline(documents))
#
# # Print the processed nodes
# print(result)
# ```
#
# ### Final Thoughts:
#
# - **Async and Parallel Processing**: This solution takes full advantage of the async and parallel processing capabilities of the `IngestionPipeline`, ensuring your pipeline is efficient and scalable.
#
# - **Caching**: By caching the results of transformations, the system avoids redundant computation, saving time on subsequent runs.
#
# - **Vector Stores**: Directly integrating with vector stores like Qdrant allows you to index and search documents easily once they are processed.
#
# - **Document Management**: Duplicate detection helps ensure that only new or modified documents are reprocessed, preventing unnecessary computation.
#
# This setup is ideal for large-scale document ingestion tasks, where performance and scalability are critical. Let me know if you need further clarifications or adjustments!

# %% [markdown]
# # Goal: to implement the above. previous basic working code:

# %% [markdown]
# # Read in all files i.e. data ingestion
#
# Basic csv reading code added. Next: use llamaparse's own data loaders

# %%
# connecting to google drive drive:
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
import os

# The CSV download link
#path = '/content/drive/MyDrive/Omdena_Challenge/PREPROCESSING/llamaparse/v0_new_LK_tea_dataset.csv'
path = '/content/v0_LK_tea_dataset.csv'

# Read the Google Sheet into a pandas DataFrame
all_data = pd.read_csv(path)
all_data.fillna('', inplace=True)
# Display the DataFrame
all_data.head()
# Out:
#    id original_class       class   filename path  \
# 0   0            ACT  regulatory  ACT_1.txt
# 1   1            ACT  regulatory  ACT_2.txt
# 2   2            ACT  regulatory  ACT_3.txt
# 3   3            ACT  regulatory  ACT_4.txt
# 4   4            ACT  regulatory  ACT_5.txt
#
#                                                  url language_label  \
# 0           https://www.lawnet.gov.lk/tea-subsidy-3/             en
# 1  https://www.lawnet.gov.lk/tea-small-holdings-d...             en
# 2  https://www.lawnet.gov.lk/tea-small-holdings-d...             en
# 3  https://www.lawnet.gov.lk/tea-small-holdings-d...             en
# 4  https://www.lawnet.gov.lk/tea-research-board-a...             en
#
#   required_ocr has_tables                                          text_path  \
# 0           no         no  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 1           no         no  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 2           no         no  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 3           no         no  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 4           no         no  /content/drive/MyDrive/Omdena_Challenge/new_LK...
#
#    ...        issuing_authority  \
# 0  ...  Parliament of Sri Lanka
# 1  ...  Parliament of Sri Lanka
# 2  ...  Parliament of Sri Lanka
# 3  ...  Parliament of Sri Lanka
# 4  ...  Parliament of Sri Lanka
#
#                                      retrieved_topic  \
# 0                               Tea Subsidy – LawNet
# 1  Tea Small Holdings Development (Amendment) – L...
# 2  Tea Small Holdings Development (Amendment) – L...
# 3        Tea Small Holdings Development Law – LawNet
# 4            Tea Research Board (Amendment) – LawNet
#
#                                         text_content PDF_or_text  \
# 0  Tea Subsidy\r\nActs Nos. 12 of 1958, 66 of 196...        Text
# 1  |\r\n\r\n**Tea Small Holdings Development (Ame...        Text
# 2  |\r\n\r\n**Tea Small Holdings Development (Ame...        Text
# 3  Tea Small Holdings Development Law\r\nA LAW TO...        Text
# 4  |\r\n\r\n**Tea Research Board (Amendment)** |\...        Text
#
#                                     markdown_content  \
# 0  # Tea Subsidy\r\n\r\nActs Nos. 12 of 1958, 66 ...
# 1  # Tea Small Holdings Development (Amendment)\r...
# 2  # Tea Small Holdings Development (Amendment)\r...
# 3  # Tea Small Holdings Development Law\r\n\r\nA ...
# 4  # Tea Research Board (Amendment)\r\n\r\n# AN A...
#
#                                          llama_title      llama_issue_date  \
# 0                    Tea Subsidy Act, No. 12 of 1958  19th September, 1958
# 1         Tea Small Holdings Development (Amendment)     12th August, 1997
# 2         Tea Small Holdings Development (Amendment)    22nd October, 2003
# 3                 Tea Small Holdings Development Law                  1975
# 4  AN ACT TO AMEND THE TEA RESEARCH BOARD ACT, NO...    6th November, 2006
#
#                llama_reference_number is_empty  \
# 0  12 of 1958, 66 of 1961, 33 of 1966    False
# 1                      No. 21 of 1997    False
# 2                  Act No. 34 of 2003    False
# 3                                  35    False
# 4                          43 of 2006    False
#
#                                        markdown_path
# 0  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 1  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 2  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 3  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 4  /content/drive/MyDrive/Omdena_Challenge/new_LK...
#
# [5 rows x 23 columns]

# %% [markdown]
# # [optional] only select tri circulers

# %%
# Select rows where 'class' is 'circular' and 'issuing_authority' is 'Tea Research Institute'
tri_circulars_df = all_data[(all_data['class'] == 'circular') & (all_data['issuing_authority'] == 'Tea Research Institute')]

# Display the selected rows
tri_circulars_df
# Out:
#     id original_class     class                                   filename  \
# 33  33      Circulers  circular            Advisory_Circular_DM1e_2024.pdf
# 34  34      Circulers  circular            Advisory_Circular_DM2e_2024.pdf
# 35  35      Circulers  circular            Advisory_Circular_DM4e_2024.pdf
# 36  36      Circulers  circular            Advisory_Circular_DM5e_2024.pdf
# 37  37      Circulers  circular            Advisory_Circular_DM6e_2024.pdf
# 38  38      Circulers  circular            Advisory_Circular_DM7e_2024.pdf
# 39  39      Circulers  circular  TRISL_Advisory_Circular_HP01e_Jun2013.pdf
# 40  40      Circulers  circular                              TRI_HP02e.pdf
# 41  41      Circulers  circular                              TRI_HP03e.pdf
# 42  42      Circulers  circular  TRISL_Advisory_Circular_HP04e_Jun2013.pdf
# 43  43      Circulers  circular            TRI_Advisory_Ciculars_LU_01.pdf
# 44  44      Circulers  circular            TRI_Advisory_Ciculars_LU_02.pdf
# 45  45      Circulers  circular                              TRI_PA01e.pdf
# 46  46      Circulers  circular                              TRI_PA02e.pdf
# 47  47      Circulers  circular                              TRI_PA03e.pdf
# 48  48      Circulers  circular           Advisory_Circular_PM-1e_2024.pdf
# 49  49      Circulers  circular           Advisory_Circular_PM-2e_2024.pdf
# 50  50      Circulers  circular           Advisory_Circular_PM-3e_2024.pdf
# 51  51      Circulers  circular           Advisory_Circular_PM-4e_2024.pdf
# 52  52      Circulers  circular           Advisory_Circular_PM-5e_2024.pdf
# 53  53      Circulers  circular           Advisory_Circular_PM-6e_2024.pdf
# 54  54      Circulers  circular           Advisory_Circular_PM-7e_2024.pdf
# 55  55      Circulers  circular           Advisory_Circular_PM-8e_2024.pdf
# 56  56      Circulers  circular           Advisory_Circular_PM-9e_2024.pdf
# 57  57      Circulers  circular          Advisory_Circular_PM-11e_2024.pdf
# 58  58      Circulers  circular          Advisory_Circular_PM-12e_2024.pdf
# 59  59      Circulers  circular            TRI_Advisory_Ciculars_PN_01.pdf
# 60  60      Circulers  circular            TRI_Advisory_Ciculars_PN_02.pdf
# 61  61      Circulers  circular                Advisory-Circular_PT-1e.pdf
# 62  62      Circulers  circular            TRI_Advisory_Ciculars_PT_03.pdf
# 63  63      Circulers  circular            TRI_Advisory_Ciculars_PT_05.pdf
# 64  64      Circulers  circular            TRI_Advisory_Ciculars_PT_06.pdf
# 65  65      Circulers  circular        TRI_Advisory_Circular_PU1e_2024.pdf
# 66  66      Circulers  circular        TRI_Advisory_Circular_PU2e_2024.pdf
# 67  67      Circulers  circular        TRI_Advisory_Circular_PU3e_2024.pdf
# 68  68      Circulers  circular            Advisory_Circular_PU4e_2024.pdf
# 69  69      Circulers  circular                              TRI_SI01e.pdf
# 70  70      Circulers  circular                              TRI_SI02e.pdf
# 71  71      Circulers  circular                              TRI_SI03e.pdf
# 72  72      Circulers  circular                              TRI_SP01e.pdf
# 73  73      Circulers  circular                              TRI_SP02e.pdf
# 74  74      Circulers  circular                              TRI_SP03e.pdf
# 75  75      Circulers  circular                              TRI_SP04e.pdf
# 76  76      Circulers  circular                              TRI_SP05e.pdf
# 77  77      Circulers  circular                              TRI_SP06e.pdf
# 78  78      Circulers  circular                              TRI_SP07e.pdf
# 79  79      Circulers  circular                              TRI_SP08e.pdf
# 80  80      Circulers  circular                              TRI_SP09e.pdf
# 81  81      Circulers  circular  TRI_Advisory_Circulars_SP_10e_Jul2016.pdf
# 82  82      Circulers  circular           Advisory_Circular_WM-1e_2024.pdf
#
#                                                  path  \
# 33  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 34  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 35  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 36  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 37  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 38  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 39  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 40  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 41  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 42  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 43  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 44  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 45  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 46  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 47  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 48  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 49  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 50  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 51  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 52  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 53  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 54  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 55  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 56  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 57  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 58  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 59  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 60  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 61  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 62  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 63  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 64  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 65  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 66  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 67  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 68  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 69  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 70  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 71  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 72  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 73  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 74  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 75  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 76  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 77  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 78  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 79  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 80  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 81  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 82  /content/drive/MyDrive/Omdena_Challenge/new_LK...
#
#                                                   url language_label  \
# 33  https://www.tri.lk/wp-content/uploads/2024/03/...             en
# 34  https://www.tri.lk/wp-content/uploads/2024/03/...             en
# 35  https://www.tri.lk/wp-content/uploads/2024/03/...             en
# 36  https://www.tri.lk/wp-content/uploads/2024/03/...             en
# 37  https://www.tri.lk/wp-content/uploads/2024/03/...             en
# 38  https://www.tri.lk/wp-content/uploads/2024/03/...             en
# 39  https://www.tri.lk/wp-content/uploads/2020/02/...             en
# 40  https://www.tri.lk/wp-content/uploads/2020/02/...             en
# 41  https://www.tri.lk/wp-content/uploads/2020/02/...             en
# 42  https://www.tri.lk/wp-content/uploads/2020/02/...             en
# 43  https://www.tri.lk/wp-content/uploads/2020/02/...             en
# 44  https://www.tri.lk/wp-content/uploads/2020/02/...             en
# 45  https://www.tri.lk/wp-content/uploads/2020/02/...             en
# 46  https://www.tri.lk/wp-content/uploads/2020/02/...             en
# 47  https://www.tri.lk/wp-content/uploads/2020/02/...             en
# 48  https://www.tri.lk/wp-content/uploads/2024/03/...             en
# 49  https://www.tri.lk/wp-content/uploads/2024/03/...             en
# 50  https://www.tri.lk/wp-content/uploads/2024/03/...             en
# 51  https://www.tri.lk/wp-content/uploads/2024/03/...             en
# 52  https://www.tri.lk/wp-content/uploads/2024/03/...             en
# 53  https://www.tri.lk/wp-content/uploads/2024/03/...             en
# 54  https://www.tri.lk/wp-content/uploads/2024/03/...             en
# 55  https://www.tri.lk/wp-content/uploads/2024/03/...             en
# 56  https://www.tri.lk/wp-content/uploads/2024/03/...             en
# 57  https://www.tri.lk/wp-content/uploads/2024/03/...             en
# 58  https://www.tri.lk/wp-content/uploads/2024/03/...             en
# 59  https://www.tri.lk/wp-content/uploads/2020/02/...             en
# 60  https://www.tri.lk/wp-content/uploads/2020/02/...             en
# 61  https://www.tri.lk/wp-content/uploads/2024/06/...             en
# 62  https://www.tri.lk/wp-content/uploads/2020/02/...             en
# 63  https://www.tri.lk/wp-content/uploads/2020/02/...             en
# 64  https://www.tri.lk/wp-content/uploads/2020/02/...             en
# 65  https://www.tri.lk/wp-content/uploads/2024/02/...             en
# 66  https://www.tri.lk/wp-content/uploads/2024/02/...             en
# 67  https://www.tri.lk/wp-content/uploads/2024/02/...             en
# 68  https://www.tri.lk/wp-content/uploads/2024/06/...             en
# 69  https://www.tri.lk/wp-content/uploads/2020/02/...             en
# 70  https://www.tri.lk/wp-content/uploads/2020/02/...             en
# 71  https://www.tri.lk/wp-content/uploads/2020/02/...             en
# 72  https://www.tri.lk/wp-content/uploads/2020/02/...             en
# 73  https://www.tri.lk/wp-content/uploads/2020/02/...             en
# 74  https://www.tri.lk/wp-content/uploads/2020/02/...             en
# 75  https://www.tri.lk/wp-content/uploads/2020/02/...             en
# 76  https://www.tri.lk/wp-content/uploads/2020/02/...             en
# 77  https://www.tri.lk/wp-content/uploads/2020/02/...             en
# 78  https://www.tri.lk/wp-content/uploads/2020/02/...             en
# 79  https://www.tri.lk/wp-content/uploads/2020/02/...             en
# 80  https://www.tri.lk/wp-content/uploads/2020/02/...             en
# 81  https://www.tri.lk/wp-content/uploads/2020/02/...             en
# 82  https://www.tri.lk/wp-content/uploads/2024/03/...             en
#
#    required_ocr has_tables text_path  ... retrieved_date_of_issuance  \
# 33          yes        yes            ...                 01/02/2024
# 34          yes         no            ...                 01/02/2024
# 35          yes        yes            ...                 01/02/2024
# 36          yes         no            ...                 01/02/2024
# 37          yes         no            ...                 01/02/2024
# 38          yes         no            ...                 01/02/2024
# 39           no        yes            ...                 01/06/2013
# 40          yes        yes            ...                 01/03/2003
# 41          yes         no            ...                 01/09/2003
# 42           no        yes            ...                 01/06/2013
# 43          yes        yes            ...                 01/10/2002
# 44          yes        yes            ...                 01/09/2003
# 45          yes         no            ...                 01/02/2001
# 46          yes         no            ...                 01/01/2011
# 47          yes         no            ...                 01/09/2003
# 48          yes        yes            ...                 01/02/2024
# 49          yes        yes            ...                 01/02/2024
# 50          yes         no            ...                 01/02/2024
# 51          yes         no            ...                 01/02/2024
# 52          yes        yes            ...                 01/02/2024
# 53          yes        yes            ...                 01/02/2024
# 54          yes        yes            ...                 01/02/2024
# 55          yes        yes            ...                 01/02/2024
# 56          yes        yes            ...                 01/02/2024
# 57          yes        yes            ...
# 58          yes        yes            ...                 01/02/2024
# 59          yes        yes            ...                 01/02/2024
# 60          yes        yes            ...                 01/12/2002
# 61          yes         no            ...                 01/11/2009
# 62          yes        yes            ...                 01/09/2003
# 63          yes         no            ...                 01/09/2003
# 64          yes         no            ...                 01/09/2003
# 65          yes        yes            ...                 01/03/2004
# 66          yes        yes            ...                 01/02/2024
# 67          yes        yes            ...                 01/02/2024
# 68          yes        yes            ...                 01/02/2024
# 69          yes         no            ...                 01/03/2024
# 70          yes        yes            ...                 01/09/2001
# 71          yes         no            ...                 01/03/2003
# 72          yes         no            ...                 01/03/2003
# 73          yes         no            ...                 01/07/2000
# 74          yes        yes            ...                 01/07/2000
# 75          yes         no            ...                 01/07/2000
# 76          yes         no            ...                 01/07/2000
# 77          yes         no            ...                 01/07/2000
# 78          yes         no            ...                 01/07/2000
# 79          yes        yes            ...                 01/05/2009
# 80          yes         no            ...                 01/05/2009
# 81          yes        yes            ...                 01/05/2009
# 82          yes        yes            ...                 01/07/2016
#
#          issuing_authority                                    retrieved_topic  \
# 33  Tea Research Institute              Protection of Tea from Blister Blight
# 34  Tea Research Institute                Protection of Tea from Root Disease
# 35  Tea Research Institute  Protection of Tea from Red Rust Disease in the...
# 36  Tea Research Institute  Protection of Tea from Stem and Branch Canker ...
# 37  Tea Research Institute  Protection of Tea from Collar and Brach Canker...
# 38  Tea Research Institute             Management of Horse-Hair Blight in Tea
# 39  Tea Research Institute                                     Pruning of Tea
# 40  Tea Research Institute                             Guidelines on Plucking
# 41  Tea Research Institute                 Cultivation of Tea Soils – Forking
# 42  Tea Research Institute                               Rejuvenation Pruning
# 43  Tea Research Institute  Guidelines on Land Suitability Classification ...
# 44  Tea Research Institute                  Field Categorization in Tea Lands
# 45  Tea Research Institute                    Bringing Young Tea Into Bearing
# 46  Tea Research Institute              Drought Mitigation in Tea Plantations
# 47  Tea Research Institute                  Infilling Vacancies in Tea Fields
# 48  Tea Research Institute          Sampling for Shot – Hole Borer Assessment
# 49  Tea Research Institute                    Management of Shot – Hole Borer
# 50  Tea Research Institute          Management Low Country Live-Wood Termites
# 51  Tea Research Institute             Protection of Young Tea from Nematodes
# 52  Tea Research Institute                     Sampling for Nematode Analysis
# 53  Tea Research Institute                                       Mite Control
# 54  Tea Research Institute                             Control of White Grubs
# 55  Tea Research Institute  Measures to avoid Contamination of Nursery Pla...
# 56  Tea Research Institute        Management of Up Country Live-Wood Termites
# 57  Tea Research Institute  Management of Tea Tortrix (Homona coffearia Ne...
# 58  Tea Research Institute  Fumigation of Nursery Soils for Nematode Eradi...
# 59  Tea Research Institute  Uprooting, Rehabilitation and Replanting of Ne...
# 60  Tea Research Institute  The Suitability of Tea Clones for the Differen...
# 61  Tea Research Institute                             Tea Nursery Management
# 62  Tea Research Institute                          Trough – Withering of Tea
# 63  Tea Research Institute              Manufacture of Tea by the CTC Process
# 64  Tea Research Institute          Calibration of Infra – Red Moisture Meter
# 65  Tea Research Institute                       Moisture Levels of Black Tea
# 66  Tea Research Institute  Pesticide (Plant Protection Product) use in Te...
# 67  Tea Research Institute                       Chemical Control of Diseases
# 68  Tea Research Institute             Chemical Control of Weeds in Tea Lands
# 69  Tea Research Institute  Chemical Control of Insect, Mite and Nematode ...
# 70  Tea Research Institute                          Green Manure Crops in Tea
# 71  Tea Research Institute                                       Shade in Tea
# 72  Tea Research Institute                      Wind and Shelter Belts in Tea
# 73  Tea Research Institute         Fertilizer Recommendations for Nursery Tea
# 74  Tea Research Institute        Fertilizer Recommendations for Immature Tea
# 75  Tea Research Institute          Fertilizer Recommendations for Mature Tea
# 76  Tea Research Institute  Fertilizer Recommendations for Clonal Mother B...
# 77  Tea Research Institute    Fertilizer Recommendations for Tea Seed Bearers
# 78  Tea Research Institute  Fertilizer Recommendations for Rehabilitation ...
# 79  Tea Research Institute                                      Soil Analysis
# 80  Tea Research Institute                     Analysis of Fertilizer Samples
# 81  Tea Research Institute                Sampling for Foliar Analysis of Tea
# 82  Tea Research Institute  Fertilizer Recommendation for Mature Tea in Sm...
#
#                                          text_content PDF_or_text  \
# 33  T.R.I. ADVISORY CIRCULAR No.DM Ei\n\n \n\nIssu...         PDF
# 34  T.R.I. ADVISORY CIRCULAR No.DM EE\n\n \n\nIssu...         PDF
# 35  T.R.I. ADVISORY CIRCULAR No.DMEg\n\n \n\nIssue...         PDF
# 36  T.R.I. ADVISORY CIRCULAR No.DM Eg\n\n \n\nIssu...         PDF
# 37  Y UC ae LG |\n\nIssued in: February 2024 Seria...         PDF
# 38  ‘s\na os\n‘| com /E T.R.I. ADVISORY CIRCULAR ~...         PDF
# 39  Issued in:June2013 Serial No.01/13\nPRUNING OF...         PDF
# 40  ADVISORY CIRCULAR _No.HP EJ\n\n \n\nIssued in:...         PDF
# 41  T.R.I. ADVISORY CIRCULAR No.HP EE\n\n \n\nIssu...         PDF
# 42  Issued in:June2013 Serial No.02/2013\nREJUVENA...         PDF
# 43  T.R.I. ADVISORY CIRCULAR __No.LU JE\n\n \n\nIs...         PDF
# 44  T.R.I. ADVISORY CIRCULAR _—No.LU EJ\n\n \n\nIs...         PDF
# 45  T.R.I. ADVISORY CIRCULAR No. PAR\n\n \n\nissue...         PDF
# 46  T.R.I. ADVISORY CIRCULAR No. PARRY\n\n \n\nIss...         PDF
# 47  T.R.I. ADVISORY CIRCULAR No. PARE\n\n \n\nIssu...         PDF
# 48  4  —*'T.R.I. ADVISORY CIRCULAR =No.PME\n\nIssu...         PDF
# 49  (@4) TRI. ADVISORY CIRCULAR _No.PMER\n\nIssued...         PDF
# 50  T.R.I. ADVISORY CIRCULAR Cm 3 |\n\n \n\nIssued...         PDF
# 51  m4) sT.R.I. ADVISORY CIRCULAR _No.PMEE\n\nIssu...         PDF
# 52  Vs\nls o\n( _¥ |. T.R.I. ADVISORY CIRCULAR No....         PDF
# 53  -\nay 2\n( Y, Js T.R.I. ADVISORY CIRCULAR No.P...         PDF
# 54  Issued in: February 2024 Serial No. 17/24\n\nC...         PDF
# 55  T.R.I. ADVISORY CIRCULAR tm Ss |\n\n \n\nIssue...         PDF
# 56     \n\n  \n \n\nT.R.I. ADVISORY CIRCULAR\n\n \...         PDF
# 57  T.R.I. ADVISORY CIRCULAR _No.PM i\n\n \n\nIssu...         PDF
# 58  T.R.I. ADVISORY CIRCULAR __No.PMEP}\n\n \n\nIs...         PDF
# 59  T.R.L. ADVISORY CIRCULAR CMe i |\n\n \n\nDate ...         PDF
# 60  ADVISORY CIRCULAR _No.PN IE\n\n \n\nIssued in:...         PDF
# 61  T.R.I. ADVISORY CIRCULAR _No.PT\n\n \n\nDate o...         PDF
# 62  T.R.I. ADVISORY CIRCULAR No.PT EE\n\n \n\nDate...         PDF
# 63    \n\n \n\n \n\n \n\n \n\n \n\n \n \n\nIssued ...         PDF
# 64  T.R.I. ADVISORY CIRCULAR __No.PT EE\n\n \n\nIs...         PDF
# 65  T.R.I. ADVISORY CIRCULAR No.PUEE\n\n \n\nIssue...         PDF
# 66  T.R.I. ADVISORY CIRCULAR No.PUPPy\n\n \n\nIssu...         PDF
# 67  T.R.I. ADVISORY CIRCULAR No.PUIEy\n\n \n\nIssu...         PDF
# 68  T.R.I. ADVISORY CIRCULAR No.PUZ®\n\n \n\nIssue...         PDF
# 69   \n\n  \n\n  \n   \n\nIssued in: September 200...         PDF
# 70    \n     \n \n \n\nua\n\n12\n\n1.3\n\n2.1\n\n2...         PDF
# 71  T.R.I. ADVISORY CIRCULAR No.S! Ei\n\n \n\nIssu...         PDF
# 72  T.R.I. ADVISORY CIRCULAR SC 1\n\n \n\nIssued i...         PDF
# 73  T.R.I. ADVISORY CIRCULAR No.SP Pj\n\n \n\nIssu...         PDF
# 74  T.R.I. ADVISORY CIRCULAR No.SP Ej\n\n \n\nIssu...         PDF
# 75  T.R.I. ADVISORY CIRCULAR No.SP Ej\n\n \n\nfssu...         PDF
# 76  T.R.L. ADVISORY CIRCULAR No.SP Ej\n\n \n\nIssu...         PDF
# 77  T.R.I. ADVISORY CIRCULAR ___No.SP\n\n \n\nIssu...         PDF
# 78  ADVISORY CIRCULAR tm 7 |\n\n \n\nIssued in: Ma...         PDF
# 79  T.R.I. ADVISORY CIRCULAR _No.SP EJ\n\n \n\nIss...         PDF
# 80  T.R.I. ADVISORY CIRCULAR No.SP [Fg\n\n \n\nIss...         PDF
# 81  9)  T.R.I. ADVISORY CIRCULAR No.SP Bt\n\nIssue...         PDF
# 82  T.R.I. ADVISORY CIRCULAR em A |\n\n \n\nIssued...         PDF
#
#                                      markdown_content  \
# 33  # ADVISORY CIRCULAR\n\n# No.DM JHL 925VynvT\n\...
# 34  # ADVISORY CIRCULAR No.DM 2\n\nIssued in: Febr...
# 35  # ADVISORY CIRCULAR No.DM 4\n\n# Issued in: Fe...
# 36  # ADVISORY CIRCULAR No.DM 5\n\nIssued in: Febr...
# 37  # ADVISORY CIRCULAR No.DM 6\n\nIssued in: Febr...
# 38  # ADVISORY CIRCULAR No.DM 4 tn 925JHLVYN\n\nIs...
# 39  # ADVISORY CIRCULAR NoHP 1\n\n# Issued in: Jun...
# 40  # ARCHWNSTLTUTE\n\n# ADVISORY CIRCULAR No.HP 2...
# 41  # ADVISORY CIRCULAR\n\n# No.HP 3\n\nIssued in:...
# 42  # ADVISORY CIRCULAR NoHP\n\nIssued in: June 20...
# 43  # INSTITUTE 9\n\n# TRI. ADVISORY CIRCULAR No_L...
# 44  # INSTITUTE\n\n# ADVISORY CIRCULAR NoLU 4\n\nI...
# 45  # TRI. ADVISORY CIRCULAR No. PA\n\nIssued in: ...
# 46  # ADVISORY CIRCULAR No. PA\n\nIssued in: Janua...
# 47  # ADVISORY CIRCULAR\n\n# No. PA 341 12\n\nIssu...
# 48  # ADVISORY CIRCULAR No.PM 4\n\nIssued in: Febr...
# 49  # ADVISORY CIRCULAR No_PM 2\n\nIssued in: Febr...
# 50  # ADVISORY CIRCULAR NoPM 3\n\nIssued in: Febru...
# 51  # ADVISORY CIRCULAR No.PM 4\n\nIssued in: Febr...
# 52  # ADVISORY CIRCULAR No.PM 5\n\n# Issued in: Fe...
# 53  # ADVISORY CIRCULAR No.PM 6\n\nIssued in: Febr...
# 54  # ADVISORY CIRCULAR\n\n# No.PM 4 TRI:\n\nIssue...
# 55  # ADVISORY CIRCULAR No.PM 8\n\nIssued in: Febr...
# 56  # ADVISORY CIRCULAR No.PM 9\n\nIssued in: Febr...
# 57  # ADVISORY CIRCULAR No.PM 11\n\n# FUMIGATION O...
# 58  # ADVISORY CIRCULAR No.PM 12 JHL 1925\n\nIssue...
# 59  # ADVISORY CIRCULAR No.PN 2\n\nDate of issue: ...
# 60  # TEA NURSERY MANAGEMENT\n\n# 1. Introduction\...
# 61  # INSTI\n\n# JHI 1925 Y\n\ntotc Woro ucod for ...
# 62  # INSTITUTE\n\n# ADVISORY CIRCULAR\n\nNo.PT 3\...
# 63  # ADVISORY CIRCULAR No_PT\n\n# CALIBRATION OF ...
# 64  # INSTITUTE\n\n# ADVISORY CIRCULAR No_PT 6\n\n...
# 65  # ADVISORY CIRCULAR No_PU 1\n\nIssued in: Febr...
# 66  # TRI ADVISORY CIRCULAR No.PU 2\n\nIssued in: ...
# 67  # ADVISORY CIRCULAR No.PU 3\n\nIssued in: Febr...
# 68  # TRI: ADVISORY CIRCULAR No.PUI 4\n\nIssued in...
# 69  # ADVISORY CIRCULAR No.SI JHI 925\n\nIssued in...
# 70  # INSTITUTE\n\n# ADVISORY CIRCULAR No.SI 925\n...
# 71  # ARCH INSTITUTE\n\n# ADVISORY CIRCULAR No.SI ...
# 72  # ADVISORY CIRCULAR No.SP JHI925\n\nIssued in:...
# 73  # ADVISORY CIRCULAR No.SP JHI925\n\nIssued in:...
# 74  # ADVISORY CIRCULAR No.SP 3\n\nIssued in: July...
# 75  # ADVISORY CIRCULAR No.SP THI 925\n\nIssued in...
# 76  # INSTITUTE\n\n# ADVISORY CIRCULAR No.SP THL 1...
# 77  # ADVISORY CIRCULAR No.SP 6\n\n# Issued in: Ju...
# 78  # ARCH\n\n# TRI. ADVISORY CIRCULAR No.SP THL 9...
# 79  # ARCH ISTITUTE\n\n# ADVISORY CIRCULAR No.SP 8...
# 80  # ADVISORY CIRCULAR No.SP 9\n\nIssued in: May ...
# 81  # ADVISORY CIRCULAR NoSP 10\n\n# Issued in: Ju...
# 82  # ADVISORY CIRCULAR No.WM TTRD JHI 1925\n\n# I...
#
#                                           llama_title  \
# 33              Protection of Tea from Blister Blight
# 34               PROTECTION OF TEA FROM ROOT DISEASES
# 35  PROTECTION OF TEA FROM RED RUST DISEASE IN THE...
# 36  PROTECTION OF TEA FROM STEM AND BRANCH CANKER ...
# 37  PROTECTION OF TEA FROM COLLAR AND BRANCH CANKE...
# 38             MANAGEMENT OF HORSE-HAIR BLIGHT IN TEA
# 39                                     PRUNING OF TEA
# 40                             Guidelines on Plucking
# 41                   CULTIVATION OF TEA SOILS FORKING
# 42                               REJUVENATION PRUNING
# 43  GUIDELINES ON LAND SUITABILITY CLASSIFICATION ...
# 44                  FIELD CATEGORIZATION IN TEA LANDS
# 45                      TRI. ADVISORY CIRCULAR No. PA
# 46              DROUGHT MITIGATION IN TEA PLANTATIONS
# 47                  INFILLING VACANCIES IN TEA FIELDS
# 48            SAMPLING FOR SHOT-HOLE BORER ASSESSMENT
# 49                      MANAGEMENT OF SHOT-HOLE BORER
# 50        MANAGEMENT OF LOW COUNTRY LIVE WOOD TERMITE
# 51             PROTECTION OF YOUNG TEA FROM NEMATODES
# 52                     SAMPLING FOR NEMATODE ANALYSIS
# 53                                       MITE CONTROL
# 54                             CONTROL OF WHITE GRUBS
# 55  MEASURES TO AVOID CONTAMINATION OF NURSERY PLA...
# 56         MANAGEMENT OF UP COUNTRY LIVE WOOD TERMITE
# 57  FUMIGATION OF NURSERY SOILS FOR NEMATODE ERADI...
# 58  ADVISORY CIRCULAR No.PM 12 JHL 1925 UPROOTING,...
# 59  THE SUITABILITY OF TEA CLONES FOR THE DIFFEREN...
# 60
# 61
# 62              MANUFACTURE OF TEA BY THE CTC PROCESS
# 63            CALIBRATION OF INFRA-RED MOISTURE METER
# 64                       MOISTURE LEVELS OF BLACK TEA
# 65  ADVISORY CIRCULAR No_PU 1 Pesticide (Plant Pro...
# 66                       CHEMICAL CONTROL OF DISEASES
# 67             CHEMICAL CONTROL OF WEEDS IN TEA LANDS
# 68  CHEMICAL CONTROL OF INSECT, MITE AND NEMATODE ...
# 69                          GREEN MANURE CROPS IN TEA
# 70        ADVVISORY CIRCULAR No.SI 925 SHADING IN TEA
# 71                      WIND AND SHELTER BELTS IN TEA
# 72         FERTILISER RECOMMENDATIONS FOR NURSERY TEA
# 73        FERTILISER RECOMMENDATIONS FOR IMMATURE TEA
# 74          FERTILISER RECOMMENDATIONS FOR MATURE TEA
# 75  FERTILISER RECOMMENDATIONS FOR CLONAL MOTHER B...
# 76    FERTILISER RECOMMENDATIONS FOR TEA SEED BEARERS
# 77  FERTILISER RECOMMENDATIONS FOR REHABILITATION ...
# 78               Tri-Advisory Circular No. SP THL 925
# 79                     Analysis of Fertilizer Samples
# 80                Sampling for Foliar Analysis of Tea
# 81  Fertilizer Recommendation for Mature Tea in Sm...
# 82                  INTEGRATED WEED MANAGEMENT IN TEA
#
#                                     llama_issue_date  \
# 33                                     February 2024
# 34                                     February 2024
# 35                                     February 2024
# 36                                     February 2024
# 37                                     February 2024
# 38                                     February 2024
# 39                                         June 2013
# 40                                        March 2003
# 41                                    September 2003
# 42                                         June 2013
# 43                                      October 2002
# 44                                    September 2003
# 45                                     February 2001
# 46                                      January 2011
# 47                                    September 2003
# 48                                     February 2024
# 49                                     February 2024
# 50                                     February 2024
# 51                                     February 2024
# 52                                     February 2024
# 53                                     February 2024
# 54                                     February 2024
# 55                                     February 2024
# 56                                     February 2024
# 57
# 58                                     February 2024
# 59                                     December 2002
# 60
# 61
# 62                                    September 2003
# 63
# 64                                        March 2004
# 65                                     February 2024
# 66                                     February 2024
# 67                                     February 2024
# 68                                        March 2024
# 69                                    September 2001
# 70                                        March 2003
# 71                                        March 2003
# 72                                      January 1996
# 73  January 1996 and July 2000 (two dates available)
# 74                                         July 2000
# 75                                         July 2000
# 76                                         July 2000
# 77                                         July 2000
# 78                                          May 2009
# 79                                          May 2009
# 80                                          May 2009
# 81                                         July 2016
# 82                                     February 2024
#
#                                llama_reference_number  \
# 33              No. DM JHL 925VynvT, Serial No. 04/24
# 34                                   Serial No. 05/24
# 35                               DM 4 Serial No 07/24
# 36                         No.DM 5 / Serial No. 08/24
# 37                                              09/24
# 38                                  DM 4 tn 925JHLVYN
# 39                                   Serial No. 01/13
# 40                                              04/03
# 41                         No.HP 3 / Serial No: 17/03
# 42                                            02/2013
# 43                                    Serial No. 3/02
# 44                                              16/03
# 45                                    Serial No. 1/01
# 46                                   Serial No. 02/11
# 47                                          PA 341 12
# 48                                              11/24
# 49                         No_PM 2 / Serial No. 12/24
# 50                                             NoPM 3
# 51                         No.PM 4 / Serial No. 14/24
# 52                                            No.PM 5
# 53          Advisory Circular PM 6 / Serial No. 16/24
# 54                         PM 4 TRI: Serial No. 17/24
# 55                                   Serial No. 18/24
# 56                                   Serial No. 19/24
# 57                             PM 11 Serial No. 05/09
# 58                                           No.PM 12
# 59                                               PN 2
# 60
# 61
# 62                          No.PT 3, Serial No: 15/03
# 63
# 64       Advisory Circular No. PT 6 / Serial No. 1/04
# 65                                   Serial No. 01/24
# 66                                            No.PU 2
# 67                                   Serial No. 03/24
# 68                                   Serial No. 25/24
# 69                                         SI JHI 925
# 70                                             SI 925
# 71                               SI 3 JHI 925 / 05/03
# 72                                       No.SP JHI925
# 73                   Circular No F 9 Serial No: 01/96
# 74                                               00/3
# 75  Circular No: F 18, Serial No.08/94 and ADVISOR...
# 76                   No.SP THL 1925 / Serial No: 00/5
# 77                                    Serial No: 00/6
# 78                                              01/09
# 79  Cancels Advisory Circular No. F6, Serial No. 6/92
# 80         Advisory Circular No.SP 9 Serial No. 03/09
# 81                                            NoSP 10
# 82                                   Serial No. 24/24
#
#                                         markdown_path
# 33  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 34  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 35  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 36  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 37  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 38  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 39  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 40  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 41  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 42  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 43  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 44  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 45  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 46  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 47  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 48  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 49  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 50  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 51  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 52  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 53  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 54  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 55  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 56  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 57  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 58  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 59  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 60  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 61  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 62  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 63  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 64  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 65  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 66  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 67  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 68  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 69  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 70  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 71  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 72  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 73  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 74  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 75  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 76  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 77  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 78  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 79  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 80  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 81  /content/drive/MyDrive/Omdena_Challenge/new_LK...
# 82  /content/drive/MyDrive/Omdena_Challenge/new_LK...
#
# [50 rows x 22 columns]

# %%
import pandas as pd

# Function to count words and characters in text
def count_words_and_characters(text):
    words = text.split()  # Split by whitespace to get words
    num_words = len(words)
    num_characters = len(text)
    return num_words, num_characters

# Function to count words and characters for the 'text_content' column in the DataFrame
def count_stats_in_dataframe(df):
    total_words = 0
    total_characters = 0

    # Iterate over the 'text_content' column in the DataFrame
    for text in df['markdown_content'].dropna():  # Drop any NaN values in text_content
        num_words, num_characters = count_words_and_characters(text)
        total_words += num_words
        total_characters += num_characters

    return total_words, total_characters

# Main script
if __name__ == "__main__":

    # Count words and characters
    total_words, total_characters = count_stats_in_dataframe(tri_circulars_df)

    # Output the results
    print("\nTotal Stats for 'markdown_content' column in DataFrame:")
    print(f"Total Words: {total_words}")
    print(f"Total Characters: {total_characters}")
# Out:
# Total Stats for 'markdown_content' column in DataFrame:
# Total Words: 52073
# Total Characters: 319861

# %% [markdown]
# # Create documents

# %%
# lot's of unused imports, will sift thru tem later

# !pip install python-dotenv
# !pip install --upgrade  llama-index llama-index-core llama-index-readers-file
# !pip install llama-index-vector-stores-lancedb
# !pip install llama_index.llms.groq llama-index-embeddings-fastembed
# Out:
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.1
# Collecting llama-index
#   Downloading llama_index-0.12.2-py3-none-any.whl.metadata (11 kB)
# Collecting llama-index-core
#   Downloading llama_index_core-0.12.2-py3-none-any.whl.metadata (2.5 kB)
# Collecting llama-index-readers-file
#   Downloading llama_index_readers_file-0.4.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting llama-index-agent-openai<0.5.0,>=0.4.0 (from llama-index)
#   Downloading llama_index_agent_openai-0.4.0-py3-none-any.whl.metadata (726 bytes)
# Collecting llama-index-cli<0.5.0,>=0.4.0 (from llama-index)
#   Downloading llama_index_cli-0.4.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting llama-index-embeddings-openai<0.4.0,>=0.3.0 (from llama-index)
#   Downloading llama_index_embeddings_openai-0.3.1-py3-none-any.whl.metadata (684 bytes)
# Collecting llama-index-indices-managed-llama-cloud>=0.4.0 (from llama-index)
#   Downloading llama_index_indices_managed_llama_cloud-0.6.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting llama-index-legacy<0.10.0,>=0.9.48 (from llama-index)
#   Downloading llama_index_legacy-0.9.48.post4-py3-none-any.whl.metadata (8.5 kB)
# Collecting llama-index-llms-openai<0.4.0,>=0.3.0 (from llama-index)
#   Downloading llama_index_llms_openai-0.3.2-py3-none-any.whl.metadata (3.3 kB)
# Collecting llama-index-multi-modal-llms-openai<0.4.0,>=0.3.0 (from llama-index)
#   Downloading llama_index_multi_modal_llms_openai-0.3.0-py3-none-any.whl.metadata (726 bytes)
# Collecting llama-index-program-openai<0.4.0,>=0.3.0 (from llama-index)
#   Downloading llama_index_program_openai-0.3.1-py3-none-any.whl.metadata (764 bytes)
# Collecting llama-index-question-gen-openai<0.4.0,>=0.3.0 (from llama-index)
#   Downloading llama_index_question_gen_openai-0.3.0-py3-none-any.whl.metadata (783 bytes)
# Collecting llama-index-readers-llama-parse>=0.4.0 (from llama-index)
#   Downloading llama_index_readers_llama_parse-0.4.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: nltk>3.8.1 in /usr/local/lib/python3.10/dist-packages (from llama-index) (3.9.1)
# Requirement already satisfied: PyYAML>=6.0.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /usr/local/lib/python3.10/dist-packages (from llama-index-core) (3.11.2)
# Collecting dataclasses-json (from llama-index-core)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: deprecated>=1.2.9.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-core) (1.2.15)
# Collecting dirtyjson<2.0.0,>=1.0.8 (from llama-index-core)
#   Downloading dirtyjson-1.0.8-py3-none-any.whl.metadata (11 kB)
# Collecting filetype<2.0.0,>=1.2.0 (from llama-index-core)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core) (2024.10.0)
# Requirement already satisfied: httpx in /usr/local/lib/python3.10/dist-packages (from llama-index-core) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /usr/local/lib/python3.10/dist-packages (from llama-index-core) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core) (3.4.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from llama-index-core) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core) (11.0.0)
# Requirement already satisfied: pydantic<2.10.0,>=2.7.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core) (2.9.2)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core) (2.32.3)
# Collecting tenacity!=8.4.0,<9.0.0,>=8.2.0 (from llama-index-core)
#   Downloading tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting tiktoken>=0.3.3 (from llama-index-core)
#   Downloading tiktoken-0.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core) (4.66.6)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core) (4.12.2)
# Collecting typing-inspect>=0.8.0 (from llama-index-core)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from llama-index-core) (1.16.0)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-readers-file) (4.12.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from llama-index-readers-file) (2.2.2)
# Collecting pypdf<6.0.0,>=5.1.0 (from llama-index-readers-file)
#   Downloading pypdf-5.1.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting striprtf<0.0.27,>=0.0.26 (from llama-index-readers-file)
#   Downloading striprtf-0.0.26-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (1.17.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (4.0.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file) (2.6)
# Requirement already satisfied: openai>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-agent-openai<0.5.0,>=0.4.0->llama-index) (1.54.4)
# Collecting llama-cloud>=0.1.5 (from llama-index-indices-managed-llama-cloud>=0.4.0->llama-index)
#   Downloading llama_cloud-0.1.5-py3-none-any.whl.metadata (763 bytes)
# Collecting llama-parse>=0.5.0 (from llama-index-readers-llama-parse>=0.4.0->llama-index)
#   Downloading llama_parse-0.5.15-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>3.8.1->llama-index) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>3.8.1->llama-index) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>3.8.1->llama-index) (2024.9.11)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<2.10.0,>=2.7.0->llama-index-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<2.10.0,>=2.7.0->llama-index-core) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->llama-index-core) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->llama-index-core) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->llama-index-core) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->llama-index-core) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core) (3.1.1)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect>=0.8.0->llama-index-core)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json->llama-index-core)
#   Downloading marshmallow-3.23.1-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core) (1.0.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx->llama-index-core) (0.14.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index-readers-file) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index-readers-file) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index-readers-file) (2024.2)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.10/dist-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core) (24.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.14.0->llama-index-agent-openai<0.5.0,>=0.4.0->llama-index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.14.0->llama-index-agent-openai<0.5.0,>=0.4.0->llama-index) (0.7.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->llama-index-core) (1.2.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->llama-index-readers-file) (1.16.0)
# Downloading llama_index-0.12.2-py3-none-any.whl (6.8 kB)
# Downloading llama_index_core-0.12.2-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 20.5 MB/s eta 0:00:00
# Downloading llama_index_readers_file-0.4.0-py3-none-any.whl (38 kB)
# Downloading dirtyjson-1.0.8-py3-none-any.whl (25 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading llama_index_agent_openai-0.4.0-py3-none-any.whl (13 kB)
# Downloading llama_index_cli-0.4.0-py3-none-any.whl (27 kB)
# Downloading llama_index_embeddings_openai-0.3.1-py3-none-any.whl (6.2 kB)
# Downloading llama_index_indices_managed_llama_cloud-0.6.3-py3-none-any.whl (11 kB)
# Downloading llama_index_legacy-0.9.48.post4-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 49.1 MB/s eta 0:00:00
# Downloading llama_index_llms_openai-0.3.2-py3-none-any.whl (13 kB)
# Downloading llama_index_multi_modal_llms_openai-0.3.0-py3-none-any.whl (5.9 kB)
# Downloading llama_index_program_openai-0.3.1-py3-none-any.whl (5.3 kB)
# Downloading llama_index_question_gen_openai-0.3.0-py3-none-any.whl (2.9 kB)
# Downloading llama_index_readers_llama_parse-0.4.0-py3-none-any.whl (2.5 kB)
# Downloading pypdf-5.1.0-py3-none-any.whl (297 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 17.0 MB/s eta 0:00:00
# Downloading striprtf-0.0.26-py3-none-any.whl (6.9 kB)
# Downloading tenacity-8.5.0-py3-none-any.whl (28 kB)
# Downloading tiktoken-0.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 51.9 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading llama_cloud-0.1.5-py3-none-any.whl (188 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.0/189.0 kB 12.7 MB/s eta 0:00:00
# Downloading llama_parse-0.5.15-py3-none-any.whl (13 kB)
# Downloading marshmallow-3.23.1-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 3.4 MB/s eta 0:00:00
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: striprtf, filetype, dirtyjson, tenacity, pypdf, mypy-extensions, marshmallow, typing-inspect, tiktoken, llama-cloud, dataclasses-json, llama-index-legacy, llama-index-core, llama-parse, llama-index-readers-file, llama-index-llms-openai, llama-index-indices-managed-llama-cloud, llama-index-embeddings-openai, llama-index-readers-llama-parse, llama-index-multi-modal-llms-openai, llama-index-cli, llama-index-agent-openai, llama-index-program-openai, llama-index-question-gen-openai, llama-index
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
# Successfully installed dataclasses-json-0.6.7 dirtyjson-1.0.8 filetype-1.2.0 llama-cloud-0.1.5 llama-index-0.12.2 llama-index-agent-openai-0.4.0 llama-index-cli-0.4.0 llama-index-core-0.12.2 llama-index-embeddings-openai-0.3.1 llama-index-indices-managed-llama-cloud-0.6.3 llama-index-legacy-0.9.48.post4 llama-index-llms-openai-0.3.2 llama-index-multi-modal-llms-openai-0.3.0 llama-index-program-openai-0.3.1 llama-index-question-gen-openai-0.3.0 llama-index-readers-file-0.4.0 llama-index-readers-llama-parse-0.4.0 llama-parse-0.5.15 marshmallow-3.23.1 mypy-extensions-1.0.0 pypdf-5.1.0 striprtf-0.0.26 tenacity-8.5.0 tiktoken-0.8.0 typing-inspect-0.9.0
# Collecting llama-index-vector-stores-lancedb
#   Downloading llama_index_vector_stores_lancedb-0.3.0-py3-none-any.whl.metadata (721 bytes)
# Collecting lancedb>=0.13.0 (from llama-index-vector-stores-lancedb)
#   Downloading lancedb-0.16.0-cp38-abi3-manylinux_2_28_x86_64.whl.metadata (4.8 kB)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-vector-stores-lancedb) (0.12.2)
# Collecting tantivy (from llama-index-vector-stores-lancedb)
#   Downloading tantivy-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.2 kB)
# Collecting deprecation (from lancedb>=0.13.0->llama-index-vector-stores-lancedb)
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: nest-asyncio~=1.0 in /usr/local/lib/python3.10/dist-packages (from lancedb>=0.13.0->llama-index-vector-stores-lancedb) (1.6.0)
# Collecting pylance==0.19.2 (from lancedb>=0.13.0->llama-index-vector-stores-lancedb)
#   Downloading pylance-0.19.2-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (7.4 kB)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.10/dist-packages (from lancedb>=0.13.0->llama-index-vector-stores-lancedb) (4.66.6)
# Requirement already satisfied: pydantic>=1.10 in /usr/local/lib/python3.10/dist-packages (from lancedb>=0.13.0->llama-index-vector-stores-lancedb) (2.9.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from lancedb>=0.13.0->llama-index-vector-stores-lancedb) (24.2)
# Collecting overrides>=0.7 (from lancedb>=0.13.0->llama-index-vector-stores-lancedb)
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: pyarrow>=12 in /usr/local/lib/python3.10/dist-packages (from pylance==0.19.2->lancedb>=0.13.0->llama-index-vector-stores-lancedb) (17.0.0)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.10/dist-packages (from pylance==0.19.2->lancedb>=0.13.0->llama-index-vector-stores-lancedb) (1.26.4)
# Requirement already satisfied: PyYAML>=6.0.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (3.11.2)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (1.2.15)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (2024.10.0)
# Requirement already satisfied: httpx in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (0.27.2)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (3.4.2)
# Requirement already satisfied: nltk>3.8.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (3.9.1)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (11.0.0)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (0.8.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (0.9.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (1.16.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (1.17.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (4.0.3)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (2024.9.11)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.10->lancedb>=0.13.0->llama-index-vector-stores-lancedb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.10->lancedb>=0.13.0->llama-index-vector-stores-lancedb) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (3.23.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (1.0.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (0.14.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (1.2.2)
# Downloading llama_index_vector_stores_lancedb-0.3.0-py3-none-any.whl (6.8 kB)
# Downloading lancedb-0.16.0-cp38-abi3-manylinux_2_28_x86_64.whl (27.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.4/27.4 MB 60.3 MB/s eta 0:00:00
# Downloading pylance-0.19.2-cp39-abi3-manylinux_2_28_x86_64.whl (30.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.5/30.5 MB 25.5 MB/s eta 0:00:00
# Downloading tantivy-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 70.6 MB/s eta 0:00:00
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Installing collected packages: tantivy, overrides, deprecation, pylance, lancedb, llama-index-vector-stores-lancedb
# Successfully installed deprecation-2.1.0 lancedb-0.16.0 llama-index-vector-stores-lancedb-0.3.0 overrides-7.7.0 pylance-0.19.2 tantivy-0.22.0
# Collecting llama_index.llms.groq
#   Downloading llama_index_llms_groq-0.3.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting llama-index-embeddings-fastembed
#   Downloading llama_index_embeddings_fastembed-0.3.0-py3-none-any.whl.metadata (697 bytes)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.0 in /usr/local/lib/python3.10/dist-packages (from llama_index.llms.groq) (0.12.2)
# Collecting llama-index-llms-openai-like<0.4.0,>=0.3.0 (from llama_index.llms.groq)
#   Downloading llama_index_llms_openai_like-0.3.0-py3-none-any.whl.metadata (751 bytes)
# Collecting fastembed>=0.2.2 (from llama-index-embeddings-fastembed)
#   Downloading fastembed-0.4.2-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: huggingface-hub<1.0,>=0.20 in /usr/local/lib/python3.10/dist-packages (from fastembed>=0.2.2->llama-index-embeddings-fastembed) (0.26.2)
# Collecting loguru<0.8.0,>=0.7.2 (from fastembed>=0.2.2->llama-index-embeddings-fastembed)
#   Downloading loguru-0.7.2-py3-none-any.whl.metadata (23 kB)
# Collecting mmh3<5.0.0,>=4.1.0 (from fastembed>=0.2.2->llama-index-embeddings-fastembed)
#   Downloading mmh3-4.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.10/dist-packages (from fastembed>=0.2.2->llama-index-embeddings-fastembed) (1.26.4)
# Collecting onnx<2.0.0,>=1.15.0 (from fastembed>=0.2.2->llama-index-embeddings-fastembed)
#   Downloading onnx-1.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Collecting onnxruntime<1.20.0,>=1.17.0 (from fastembed>=0.2.2->llama-index-embeddings-fastembed)
#   Downloading onnxruntime-1.19.2-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Collecting pillow<11.0.0,>=10.3.0 (from fastembed>=0.2.2->llama-index-embeddings-fastembed)
#   Downloading pillow-10.4.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Collecting py-rust-stemmers<0.2.0,>=0.1.0 (from fastembed>=0.2.2->llama-index-embeddings-fastembed)
#   Downloading py_rust_stemmers-0.1.3-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: requests<3.0,>=2.31 in /usr/local/lib/python3.10/dist-packages (from fastembed>=0.2.2->llama-index-embeddings-fastembed) (2.32.3)
# Requirement already satisfied: tokenizers<1.0,>=0.15 in /usr/local/lib/python3.10/dist-packages (from fastembed>=0.2.2->llama-index-embeddings-fastembed) (0.20.3)
# Requirement already satisfied: tqdm<5.0,>=4.66 in /usr/local/lib/python3.10/dist-packages (from fastembed>=0.2.2->llama-index-embeddings-fastembed) (4.66.6)
# Requirement already satisfied: PyYAML>=6.0.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (3.11.2)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (1.2.15)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (2024.10.0)
# Requirement already satisfied: httpx in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (3.4.2)
# Requirement already satisfied: nltk>3.8.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (3.9.1)
# Requirement already satisfied: pydantic<2.10.0,>=2.7.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (2.9.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (0.8.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (0.9.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (1.16.0)
# Requirement already satisfied: llama-index-llms-openai<0.4.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-llms-openai-like<0.4.0,>=0.3.0->llama_index.llms.groq) (0.3.2)
# Requirement already satisfied: transformers<5.0.0,>=4.37.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-llms-openai-like<0.4.0,>=0.3.0->llama_index.llms.groq) (4.46.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (1.17.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (4.0.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.20->fastembed>=0.2.2->llama-index-embeddings-fastembed) (3.16.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.20->fastembed>=0.2.2->llama-index-embeddings-fastembed) (24.2)
# Requirement already satisfied: openai<2.0.0,>=1.40.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-llms-openai<0.4.0,>=0.3.0->llama-index-llms-openai-like<0.4.0,>=0.3.0->llama_index.llms.groq) (1.54.4)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (2024.9.11)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from onnx<2.0.0,>=1.15.0->fastembed>=0.2.2->llama-index-embeddings-fastembed) (4.25.5)
# Collecting coloredlogs (from onnxruntime<1.20.0,>=1.17.0->fastembed>=0.2.2->llama-index-embeddings-fastembed)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime<1.20.0,>=1.17.0->fastembed>=0.2.2->llama-index-embeddings-fastembed) (24.3.25)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime<1.20.0,>=1.17.0->fastembed>=0.2.2->llama-index-embeddings-fastembed) (1.13.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<2.10.0,>=2.7.0->llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<2.10.0,>=2.7.0->llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.31->fastembed>=0.2.2->llama-index-embeddings-fastembed) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.31->fastembed>=0.2.2->llama-index-embeddings-fastembed) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.31->fastembed>=0.2.2->llama-index-embeddings-fastembed) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.31->fastembed>=0.2.2->llama-index-embeddings-fastembed) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (3.1.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.37.0->llama-index-llms-openai-like<0.4.0,>=0.3.0->llama_index.llms.groq) (0.4.5)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (3.23.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (1.0.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (0.14.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.40.0->llama-index-llms-openai<0.4.0,>=0.3.0->llama-index-llms-openai-like<0.4.0,>=0.3.0->llama_index.llms.groq) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.40.0->llama-index-llms-openai<0.4.0,>=0.3.0->llama-index-llms-openai-like<0.4.0,>=0.3.0->llama_index.llms.groq) (0.7.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (1.2.2)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime<1.20.0,>=1.17.0->fastembed>=0.2.2->llama-index-embeddings-fastembed)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime<1.20.0,>=1.17.0->fastembed>=0.2.2->llama-index-embeddings-fastembed) (1.3.0)
# Downloading llama_index_llms_groq-0.3.0-py3-none-any.whl (2.9 kB)
# Downloading llama_index_embeddings_fastembed-0.3.0-py3-none-any.whl (2.7 kB)
# Downloading fastembed-0.4.2-py3-none-any.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 3.2 MB/s eta 0:00:00
# Downloading llama_index_llms_openai_like-0.3.0-py3-none-any.whl (3.1 kB)
# Downloading loguru-0.7.2-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 4.6 MB/s eta 0:00:00
# Downloading mmh3-4.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 4.9 MB/s eta 0:00:00
# Downloading onnx-1.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 58.7 MB/s eta 0:00:00
# Downloading onnxruntime-1.19.2-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (13.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 64.2 MB/s eta 0:00:00
# Downloading pillow-10.4.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 52.4 MB/s eta 0:00:00
# Downloading py_rust_stemmers-0.1.3-cp310-cp310-manylinux_2_28_x86_64.whl (323 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.9/323.9 kB 16.7 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.9 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 5.9 MB/s eta 0:00:00
# Installing collected packages: py-rust-stemmers, mmh3, pillow, onnx, loguru, humanfriendly, coloredlogs, onnxruntime, fastembed, llama-index-embeddings-fastembed, llama-index-llms-openai-like, llama_index.llms.groq
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.0.0
#     Uninstalling pillow-11.0.0:
#       Successfully uninstalled pillow-11.0.0
# Successfully installed coloredlogs-15.0.1 fastembed-0.4.2 humanfriendly-10.0 llama-index-embeddings-fastembed-0.3.0 llama-index-llms-openai-like-0.3.0 llama_index.llms.groq-0.3.0 loguru-0.7.2 mmh3-4.1.0 onnx-1.17.0 onnxruntime-1.19.2 pillow-10.4.0 py-rust-stemmers-0.1.3

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
# basic official code

# from llama_index.core import VectorStoreIndex

# documents = LlamaParse(result_type="markdown").load_data("/content/drive/MyDrive/Tea/ocr_results/Manual_Pdf/Docs_Tables/03_Sri-Lanka-Tea-Board-Standads-for-Other-Origin-Teas_compressed.pdf")

# # create an index from the parsed markdown
# index = VectorStoreIndex.from_documents(documents)

# # create a query engine for the index
# query_engine = index.as_query_engine()

# # query the engine
# query = "What can you do in the Bay of Fundy?"
# response = query_engine.query(query)
# print(response)

# %% [markdown]
# counter intuitive to run llamaparse again, esp for markdown which is already good format, and also harder to add metadata to each file

# %%
# import pandas as pd
# from llama_parse import LlamaParse
# import asyncio

# # Initialize parsers
# markdown_parser = LlamaParse(result_type='markdown', Set_fast_mode=True, num_workers=8)

# # Async function to process Markdown documents
# async def process_markdown_documents(markdown_paths):
#     if markdown_paths:
#         return await asyncio.to_thread(
#             lambda: SimpleDirectoryReader(input_files=markdown_paths, file_extractor={".md": markdown_parser}).load_data()
#         )
#     return []

# # Async function to process and return documents from DataFrame
# async def process_and_save_df(all_data):
#     markdown_paths = all_data['markdown_path'].tolist()
#     return await process_markdown_documents(markdown_paths)

# # Main function to execute the async processing
# async def main():
#     processed_documents = await process_and_save_df(all_data)
#     if processed_documents:
#         return processed_documents
#     print("No documents to process.")
#     return []

# # Run the asynchronous main function
# processed_documents = asyncio.run(main())

# %% [markdown]
# https://docs.llamaindex.ai/en/stable/module_guides/loading/simpledirectoryreader/

# %% [markdown]
# just some reference codes

# %%
# from llama_index.core import SimpleDirectoryReader

# filename_fn = lambda filename: {"file_name": filename}

# # automatically sets the metadata of each document according to filename_fn
# documents = SimpleDirectoryReader(
#     "./data", file_metadata=filename_fn
# ).load_data()

# %%
# reader = SimpleDirectoryReader(input_dir="path/to/directory", recursive=True)
# all_docs = []
# for docs in reader.iter_data():
#     # <do something with the documents per file>
#     all_docs.extend(docs)

# %%
# from llama_index.core import Document
# from llama_index.core.schema import MetadataMode

# document = Document(
#     text="This is a super-customized document",
#     metadata={
#         "file_name": "super_secret_document.txt",
#         "category": "finance",
#         "author": "LlamaIndex",
#     },
#     excluded_llm_metadata_keys=["file_name"],
#     metadata_seperator="::",
#     metadata_template="{key}=>{value}",
#     text_template="Metadata: {metadata_str}\n-----\nContent: {content}",
# )

# print(
#     "The LLM sees this: \n",
#     document.get_content(metadata_mode=MetadataMode.LLM),
# )
# print(
#     "The Embedding model sees this: \n",
#     document.get_content(metadata_mode=MetadataMode.EMBED),
# )

# %%
# epic faillllllllllll
# import pandas as pd
# from llama_index.core import SimpleDirectoryReader
# import asyncio

# # Function to get metadata from DataFrame based on file_path
# def get_meta(file_path):
#     matching_row = tri_circulars_df[tri_circulars_df['markdown_path'] == file_path].iloc[0] if not tri_circulars_df[tri_circulars_df['markdown_path'] == file_path].empty else None
#     if matching_row is None:
#         return {
#             "class": 'Unknown',
#             "issuing_authority": 'Unknown',
#             "has_tables": False,
#             "llama_title": 'Unknown Title',
#             "llama_issue_date": 'Unknown Date',
#             "llama_reference_number": 'Unknown Reference'
#         }
#     return {
#         "class": matching_row['class'],
#         "issuing_authority": matching_row['issuing_authority'],
#         "has_tables": matching_row.get('has_tables', False),
#         "llama_title": matching_row.get('llama_title', 'Unknown Title'),
#         "llama_issue_date": matching_row.get('llama_issue_date', 'Unknown Date'),
#         "llama_reference_number": matching_row.get('llama_reference_number', 'Unknown Reference')
#     }

# # Async function to load markdown files and extract documents
# async def load_documents():
#     markdown_paths = tri_circulars_df['markdown_path'].tolist()
#     if markdown_paths:
#         # Await the asynchronous loading of data
#         documents = await asyncio.to_thread(
#             lambda: SimpleDirectoryReader(input_files=markdown_paths, file_metadata=get_meta).aload_data()
#         )
#         return documents
#     return []

# # Async main function
# async def main():
#     documents = await load_documents()  # Ensure to await this
#     print("documents loaded")  # Now it can access len() since documents are awaited
#     return documents

# # Run the async main function
# documents = asyncio.run(main())
# Out:
# documents loaded

# %% [markdown]
# main async document loader

# %%
import pandas as pd
from llama_index.core import SimpleDirectoryReader
import asyncio


df_for_loading = all_data.copy()  # can use tri_circulars_df alternatively
# Function to get metadata from DataFrame based on file_path
def get_meta(file_path):
    matching_row = df_for_loading[df_for_loading['markdown_path'] == file_path].iloc[0] if not df_for_loading[df_for_loading['markdown_path'] == file_path].empty else None
    if matching_row is None:
        return {
            "filename": 'Unknown',
            "class": 'Unknown',
            "issuing_authority": 'Unknown',
            "has_tables": False,
            "llama_title": 'Unknown Title',
            "llama_issue_date": 'Unknown Date',
            "llama_reference_number": 'Unknown Reference'
        }
    return {
        "filename": matching_row['filename'], # included in reference number and issue date and title
        "class": matching_row['class'], # included in issuing_authority, also good becuase regulation doesn't really cover egz, because it is laws+regulation, and its issuing authority says egz, not regulation
        "issuing_authority": matching_row['issuing_authority'],
        "has_tables": matching_row.get('has_tables', False),
        "llama_title": matching_row.get('llama_title', 'Unknown Title'),
        "llama_issue_date": matching_row.get('llama_issue_date', 'Unknown Date'),
        "llama_reference_number": matching_row.get('llama_reference_number', 'Unknown Reference')
    }



markdown_paths = df_for_loading['markdown_path'].tolist()
# Create a SimpleDirectoryReader instance
reader = SimpleDirectoryReader(input_files=markdown_paths, filename_as_id=True, file_metadata=get_meta)
# Asynchronously load data
documents = await reader.aload_data()

# %%
print([document.doc_id for document in documents])
# Out:
# ['/content/drive/MyDrive/Omdena_Challenge/new_LK_tea_dataset/ACT/ACT_1.md_part_0', '/content/drive/MyDrive/Omdena_Challenge/new_LK_tea_dataset/ACT/ACT_1.md_part_1', '/content/drive/MyDrive/Omdena_Challenge/new_LK_tea_dataset/ACT/ACT_1.md_part_2', '/content/drive/MyDrive/Omdena_Challenge/new_LK_tea_dataset/ACT/ACT_1.md_part_3', '/content/drive/MyDrive/Omdena_Challenge/new_LK_tea_dataset/ACT/ACT_1.md_part_4', '/content/drive/MyDrive/Omdena_Challenge/new_LK_tea_dataset/ACT/ACT_1.md_part_5', '/content/drive/MyDrive/Omdena_Challenge/new_LK_tea_dataset/ACT/ACT_1.md_part_6', '/content/drive/MyDrive/Omdena_Challenge/new_LK_tea_dataset/ACT/ACT_1.md_part_7', '/content/drive/MyDrive/Omdena_Challenge/new_LK_tea_dataset/ACT/ACT_1.md_part_8', '/content/drive/MyDrive/Omdena_Challenge/new_LK_tea_dataset/ACT/ACT_1.md_part_9', '/content/drive/MyDrive/Omdena_Challenge/new_LK_tea_dataset/ACT/ACT_1.md_part_10', '/content/drive/MyDrive/Omdena_Challenge/new_LK_tea_dataset/ACT/ACT_1.md_part_11', '/content/drive/MyDrive/Omdena_Challenge/new_LK_tea_dataset/ACT/ACT_1.md_part_12', '/content/drive/MyDrive/Omdena_Challenge/new_LK_tea_dataset/ACT/ACT_1.md_part_13', '/content/drive/MyDrive/Omdena_Challenge/new_LK_tea_dataset/ACT/ACT_1.md_part_14', '/content/drive/MyDrive/Omdena_Challenge/new_LK_tea_dataset/ACT/ACT_1.md_part_15', '/content/drive/MyDrive/Omdena_Challenge/new_LK_tea_dataset/ACT/ACT_1.md_part_16', '/content/drive/MyDrive/Omdena_Challenge/new_LK_tea_dataset/ACT/ACT_1.md_part_17', '/content/drive/MyDrive/Omdena_Challenge/new_LK_tea_dataset/ACT/ACT_1.md_part_18', '/content/drive/MyDrive/Omdena_Challenge/new_LK_tea_dataset/ACT/ACT_1.md_part_19', '/content/drive/MyDrive/Omdena_Challenge/new_LK_tea_dataset/ACT/ACT_1.md_part_20', '/content/drive/MyDrive/Omdena_Challenge/new_LK_tea_dataset/ACT/ACT_1.md_part_21', '/content/drive/MyDrive/Omdena_Challenge/new_LK_tea_dataset/ACT/ACT_1.md_part_22', '/content/drive/MyDrive/Omdena_Challenge/new_LK_tea_dataset/ACT/ACT_1.md_part_23', '/content/drive/MyDrive/Omdena_Challenge/new_LK_tea_dataset/ACT/ACT_1.md_part_24', '/content/drive/MyDrive/Omdena_Challenge/new_LK_tea_dataset/ACT/ACT_2.md_part_0', '/content/drive/MyDrive/Omdena_Challenge/new_LK_tea_dataset/ACT/ACT_2.md_part_1', '/content/drive/MyDrive/Omdena_Challenge/new_LK_tea_dataset/ACT/ACT_2.md_part_2', '/content/drive/MyDrive/Omdena_Challenge/new_LK_tea_dataset/ACT/ACT_2.md_part_3', '/content/drive/MyDrive/Omdena_Challenge/new_LK_tea_dataset/ACT/ACT_2.md_part_4', '/content/drive/MyDrive/Omdena_Challenge/new_LK_tea_dataset/ACT/ACT_2.md_part_5', '/content/drive/MyDrive/Omdena_Challenge/new_LK_tea_dataset/ACT/ACT_2.md_part_6', '/content/drive/MyDrive/Omdena_Challenge/new_LK_tea_dataset/ACT/ACT_3.md_part_0', '/content/drive/MyDrive/Omdena_Challenge/new_LK_tea_dataset/ACT/ACT_3.md_part_1', '/content/drive/MyDrive/Omdena_Challenge/new_LK_tea_dataset/ACT/ACT_3.md_part_2', '/content/drive/MyDrive/Omdena_Challenge/new_LK_tea_dataset/ACT/ACT_3.md_part_3', '/content/drive/MyDrive/Omdena_Challenge/new_LK_tea_dataset/ACT/ACT_3.md_part_4', '/content/drive/MyDrive/Omdena_Challenge/new_LK_tea_dataset/ACT/ACT_3.md_part_5', '/content/drive/MyDrive/Omdena_Challenge/new_LK_tea_dataset/ACT/ACT_3.md_part_6', '/content/drive/MyDrive/Omdena_Challenge/new_LK_tea_dataset/ACT/ACT_3.md_part_7', '/content/drive/MyDrive/Omdena_Challenge/new_LK_tea_dataset/ACT/ACT_3.md_part_8', '/content/drive/MyDrive/Omdena_Challenge/new_LK_tea_dataset/ACT/ACT_3.md_part_9', '/content/drive/MyDrive/Omdena_Challenge/new_LK_tea_dataset/ACT/ACT_3.md_part_10', '/content/drive/MyDrive/Omdena_Challenge/new_LK_tea_dataset/ACT/ACT_3.md_part_11', '/content/drive/MyDrive/Omdena_Challenge/new_LK_tea_dataset/ACT/ACT_4.md_part_0', '/content/drive/MyDrive/Omdena_Challenge/new_LK_tea_dataset/ACT/ACT_4.md_part_1', '/content/drive/MyDrive/Omdena_Challenge/new_LK_tea_dataset/ACT/ACT_4.md_part_2', '/content/drive/MyDrive/Omdena_Challenge/new_LK_tea_dataset/ACT/ACT_4.md_part_3', '/content/drive/MyDrive/Omdena_Challenge/new_L ...

# %%
for document in documents:
  document.excluded_llm_metadata_keys = ['file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date', 'has_tables'] #llm gets biased becuase of issuing_authority which is TRI circulars, or government of Sri Lanka egz
  document.excluded_embed_metadata_keys = ['file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date']

# %%
from llama_index.core.schema import MetadataMode

print(documents[0].get_content(metadata_mode=MetadataMode.LLM))
# Out:
# filename: ACT_1.txt
# class: regulatory
# issuing_authority: Parliament of Sri Lanka
# llama_title: Tea Subsidy Act, No. 12 of 1958
# llama_issue_date: 19th September, 1958
# llama_reference_number: 12 of 1958, 66 of 1961, 33 of 1966
#
#
#
# Tea Subsidy
#
# Acts Nos. 12 of 1958, 66 of 1961. 33 of 1966.

# %%
from llama_index.core.schema import MetadataMode

print(documents[0].get_content(metadata_mode=MetadataMode.EMBED))
# Out:
# filename: ACT_1.txt
# class: regulatory
# issuing_authority: Parliament of Sri Lanka
# has_tables: no
# llama_title: Tea Subsidy Act, No. 12 of 1958
# llama_issue_date: 19th September, 1958
# llama_reference_number: 12 of 1958, 66 of 1961, 33 of 1966
#
#
#
# Tea Subsidy
#
# Acts Nos. 12 of 1958, 66 of 1961. 33 of 1966.

# %%
documents[0]
# Out:
# Document(id_='/content/drive/MyDrive/Omdena_Challenge/new_LK_tea_dataset/ACT/ACT_1.md_part_0', embedding=None, metadata={'filename': 'ACT_1.txt', 'class': 'regulatory', 'issuing_authority': 'Parliament of Sri Lanka', 'has_tables': 'no', 'llama_title': 'Tea Subsidy Act, No. 12 of 1958', 'llama_issue_date': '19th September, 1958', 'llama_reference_number': '12 of 1958, 66 of 1961, 33 of 1966'}, excluded_embed_metadata_keys=['file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date', 'has_tables'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='\n\nTea Subsidy\n\r\nActs Nos. 12 of 1958, 66 of 1961. 33 of 1966.\r\n\r', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}')

# %% [markdown]
# # test 1: [BASELINE llama 3 70b][LOCAL] Create temp lancedb vector index and query the parsed documents
# not the ones saved as csv (that is for our viewing), but the variable returned by llamaparse
#
# llama 3 70b works great on longer context, but when we start extracting metadata per node, we need a model that allows more token and requests per day on groq

# %%
from llama_index.core.node_parser import MarkdownNodeParser


node_parser = MarkdownNodeParser()
nodes = node_parser.get_nodes_from_documents(documents)

# %%
nodes[0]
# Out:
# TextNode(id_='5bce4ae7-7cc6-4d1c-9a47-f7c2c0bcfc4c', embedding=None, metadata={'filename': 'ACT_1.txt', 'class': 'regulatory', 'issuing_authority': 'Parliament of Sri Lanka', 'has_tables': 'no', 'llama_title': 'Tea Subsidy Act, No. 12 of 1958', 'llama_issue_date': '19th September, 1958', 'llama_reference_number': '12 of 1958, 66 of 1961, 33 of 1966', 'header_path': '/'}, excluded_embed_metadata_keys=['file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date', 'has_tables'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='/content/drive/MyDrive/Omdena_Challenge/new_LK_tea_dataset/ACT/ACT_1.md_part_0', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'filename': 'ACT_1.txt', 'class': 'regulatory', 'issuing_authority': 'Parliament of Sri Lanka', 'has_tables': 'no', 'llama_title': 'Tea Subsidy Act, No. 12 of 1958', 'llama_issue_date': '19th September, 1958', 'llama_reference_number': '12 of 1958, 66 of 1961, 33 of 1966'}, hash='9d4d8a7aa242e75df058cabeae6b18fd85e5a283443653facfcef1301678b89d')}, metadata_template='{key}: {value}', metadata_separator='\n', text='Tea Subsidy\n\r\nActs Nos. 12 of 1958, 66 of 1961. 33 of 1966.', mimetype='text/plain', start_char_idx=2, end_char_idx=61, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}')

# %% [markdown]
# ### currently here

# %%
# basic vecor store
# from llama_index.core import VectorStoreIndex

# vector_index = VectorStoreIndex.from_documents(documents)
# vector_index.as_query_engine()

# %%
import os
import getpass

# # os.environ['LLAMA_CLOUD_API_KEY'] = getpass.getpass('Enter your LLamacloud API Key: ')
os.environ['GROQ_API_KEY'] = getpass.getpass('Enter your GROQ API Key: ')
# Out:
# Enter your GROQ API Key: ··········

# %%
from llama_index.llms.groq import Groq
from llama_index.embeddings.fastembed import FastEmbedEmbedding


embed_model = FastEmbedEmbedding(model_name="BAAI/bge-small-en-v1.5")
llm = Groq(model="llama3-70b-8192", api_key=os.environ['GROQ_API_KEY'], temperature=0.0)
# Out:
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
# # can use the previous simple node parser or this whole ingestion pipeline
# # right now used simple nodeparser, used this one with kdb.ai code below

# from llama_index.core.extractors import (
#     TitleExtractor,
#     QuestionsAnsweredExtractor,
# )
# from llama_index.core.node_parser import MarkdownNodeParser


# node_parser = MarkdownNodeParser()
# # text_splitter = TokenTextSplitter(
# #     separator=" ", chunk_size=512, chunk_overlap=128
# # )
# title_extractor = TitleExtractor(llm = llm, nodes=5)
# qa_extractor = QuestionsAnsweredExtractor(llm = llm, questions=3)

# # assume documents are defined -> extract nodes
# from llama_index.core.ingestion import IngestionPipeline

# pipeline = IngestionPipeline(
#     transformations=[node_parser, title_extractor, qa_extractor]
# )

# nodes = pipeline.run(
#     documents=documents,
#     in_place=True,
#     show_progress=True,
# )

# %%
from llama_index.vector_stores.lancedb import LanceDBVectorStore
from llama_index.core import VectorStoreIndex
from llama_index.core import StorageContext

vector_store_lancedb = LanceDBVectorStore(uri="/tmp/lancedb_lamaindex")
storage_context = StorageContext.from_defaults(vector_store=vector_store_lancedb)

index = VectorStoreIndex(
    nodes=nodes,
    storage_context=storage_context,
    embed_model=embed_model,
)

query_engine = index.as_query_engine(similarity_top_k=5, llm=llm)

# %%
query = "What is relation between law, regulation, circular and guideline? give examples from filenames, and format as paragraph"
response_1 = query_engine.query(query)
print("\n**LlamaParse+ Lamaindex**")
print(response_1)
# Out:
# **LlamaParse+ Lamaindex**
# The relationship between law, regulation, circular, and guideline can be understood as a hierarchical structure. Laws are the highest authority, providing the overall framework. Regulations are derived from laws, outlining specific rules and procedures. Circulars, such as OR/1/51, are issued by authorities like the Tea Board, providing detailed instructions and clarifications on implementing regulations. Guidelines, although not explicitly mentioned, can be seen as internal documents providing additional guidance on circulars. For instance, the Sri Lanka Tea Board might have internal guidelines on how to implement the directives outlined in Circular OR/1/51.

# %%
query = "Should laws and regulations be put in the same class for effective information retrieval? format as paragraph"
response_1 = query_engine.query(query)
print("\n**LlamaParse+ Lamaindex**")
print(response_1)
# Out:
# **LlamaParse+ Lamaindex**
# It appears that laws and regulations are distinct types of documents, each serving a specific purpose. Laws, as represented by the "GAZETTE EXTRAORDINARY OF THE DEMOCRATIC SOCIALIST REPUBLIC OF SRI LANKA", are official government publications that contain new legislation or amendments to existing laws. On the other hand, regulations, as exemplified by the "CIRCULAR" issued by the Tea Board, are guidelines or rules that govern specific industries or sectors. Given their different natures and purposes, it may be beneficial to categorize them separately for effective information retrieval, allowing users to quickly identify and access the relevant type of document.

# %%
query = "Are acts, laws, and extra gazettes semantically similar and can they be put in the same class for effective information retrieval?"
response_1 = query_engine.query(query)
print("\n**LlamaParse+ Lamaindex**")
print(response_1)
# Out:
# **LlamaParse+ Lamaindex**
# Based on the provided context, it appears that "GAZETTE EXTRAORDINARY OF THE DEMOCRATIC SOCIALIST REPUBLIC OF SRI LANKA" is a type of official document issued by the Government of Sri Lanka, which suggests that it may contain laws, acts, or other regulatory information.
#
# Given this, it can be inferred that gazettes, laws, and acts share a similar purpose and content, implying a certain level of semantic similarity. Therefore, it is reasonable to group them into the same class, which would facilitate effective information retrieval for users searching for related official documents or regulatory information.

# %%
query = "give common topics and patterns of each class of documents i.e regulatory, circular, and guideline"
response_1 = query_engine.query(query)
print("\n**LlamaParse+ Lamaindex**")
print(response_1)
# Out:
# **LlamaParse+ Lamaindex**
# Based on the provided context information, here are the common topics and patterns for each class of documents:
#
# **Circular:**
#
# * Topics: Exportation of tea, preparation of customs goods declaration, and related procedures.
# * Patterns: The documents in this class have a specific format, including a reference number, issue date, and a clear title indicating the purpose of the circular. They provide instructions or guidelines for a specific process or procedure.
#
# **Guideline:**
#
# * Topics: Standards and guidelines for tea, quality control, and related regulations.
# * Patterns: The documents in this class provide detailed guidelines and standards for the tea industry, including specifications and requirements for tea production and exportation. They are often issued by a regulatory authority and have a formal tone.
#
# **Regulatory:**
#
# * (No documents in this class are provided in the context information)
#
# Note: Since there are no documents in the "Regulatory" class, it is not possible to identify common topics and patterns for this class based on the provided context information.

# %%
query = "give common topics and patterns of each issuing authority of documents"
response_1 = query_engine.query(query)
print("\n**LlamaParse+ Lamaindex**")
print(response_1)
# Out:
# **LlamaParse+ Lamaindex**
# Based on the provided information, the following common topics and patterns can be observed for each issuing authority:
#
# **Government of Sri Lanka**
#
# * Topic: Gazette publications, regulatory documents
# * Pattern: The documents issued by the Government of Sri Lanka seem to be gazette publications, which are official documents that contain laws, regulations, and other important announcements.
#
# **Tea Board**
#
# * Topic: Tea exportation, customs regulations
# * Pattern: The document issued by the Tea Board appears to be related to the exportation of tea and the preparation of customs goods declaration forms, suggesting that the Tea Board is responsible for regulating and guiding the tea industry in Sri Lanka.

# %%
query = "give best node parser to optimize RAG chatbot for each class of documents"
response_1 = query_engine.query(query)
print("\n**LlamaParse+ Lamaindex**")
print(response_1)
# Out:
# **LlamaParse+ Lamaindex**
# For the class of circular documents, I recommend using a Node Parser that leverages the structured format of the documents. A suitable parser would be the `xml2js` parser, which can efficiently extract relevant information from the circular documents. This parser is particularly effective in handling the hierarchical structure of the documents, making it easier to optimize the RAG chatbot for this class of documents.

# %%
query = "which appraoch should I take to optimize RAG chatbot in terms of vector databases and graph databases for each class of documents"
response_1 = query_engine.query(query)
print("\n**LlamaParse+ Lamaindex**")
print(response_1)
# Out:
# **LlamaParse+ Lamaindex**
# To optimize the RAG chatbot, a hybrid approach can be taken. For the "circular" class of documents, a vector database can be utilized to store and query the semantic embeddings of the documents. This will enable efficient similarity searches and clustering of similar documents.
#
# On the other hand, a graph database can be employed to store the relationships between the different entities mentioned in the documents, such as the issuing authorities, reference numbers, and dates. This will facilitate querying and traversal of the graph to uncover connections between entities.
#
# By combining these two approaches, the RAG chatbot can leverage the strengths of both vector and graph databases to provide more accurate and informative responses to user queries.

# %%
query = "will keyowrk based indexing give good retrival results? discuss for each class of documents"
response_1 = query_engine.query(query)
print("\n**LlamaParse+ Lamaindex**")
print(response_1)
# Out:
# **LlamaParse+ Lamaindex**
# Based on the provided context information, we can analyze the documents and discuss the effectiveness of keyword-based indexing for each class of documents.
#
# The documents belong to the class "circular" and are issued by the Tea Board. They contain specific information related to the tea industry, such as regulations, guidelines, and application forms.
#
# For the class "circular," keyword-based indexing might be effective for retrieving documents that contain specific keywords related to the tea industry, such as "tea auction," "licensed tea brokers," "handwritten marks," "warehouse registration," "payment of reasonable price," and "damaged made tea." These keywords are likely to be relevant and frequently occurring in the documents, making it easier to retrieve them using keyword-based indexing.
#
# However, there are some limitations to consider:
#
# 1. **Domain-specific terminology**: The documents contain domain-specific terminology, such as "Trav. No/s," "Garden Marks," and "Factory Re-Return," which might not be well-represented in a general-purpose keyword-based indexing system. This could lead to poor retrieval results if the indexing system is not tailored to the tea industry domain.
# 2. **Structural complexity**: Some documents, like the "Application for Approval to Dispose of Damaged Made Tea" (OR 1 51 I.pdf), contain complex structures like tables and forms. Keyword-based indexing might struggle to effectively capture the relationships between the different fields and sections in these documents, leading to suboptimal retrieval results.
# 3. **Variability in document structure**: The documents exhibit varying structures, such as the "RENEWAL NEW REGISTRATION OF WAREHOUSE FOR IK" (TC-EX-WH-P.pdf) document, which contains a list of required documents and a deadline for submission. This variability might make it challenging for a keyword-based indexing system to accurately capture the relevant information and relationships between different sections.
#
# To improve the effectiveness of keyword-based indexing for this class of documents, it might be necessary to:
#
# * Develop a domain-specific thesaurus or ontology to capture the nuances of the tea industry terminology.
# * Implement a more sophisticated indexing approach that can handle structural complexity, such as using XML-based indexing or graph-based indexing.
# * Use natural language processing (NLP) techniques to better understand the relationships between different sections and fields in the documents.
#
# In conclusion, while keyword-based indexing can be effective for retrieving documents that contain specific keywords related to the tea industry, it may not be sufficient to capture the complexity and variability of the documents in this class. A more tailored approach, incorporating domain-specific knowledge and advanced indexing techniques, might be necessary to achieve optimal retrieval results.

# %%
query = "should I use sparse or dense vectors for similairty search for retrieval? discuss for each class of documents?"
response_1 = query_engine.query(query)
print("\n**LlamaParse+ Lamaindex**")
print(response_1)
# Out:
# **LlamaParse+ Lamaindex**
# Based on the provided context, it appears that the documents are related to the Tea Board and contain circulars, instructions, and guidelines for tea exporters, manufacturers, and traders. The content of the documents seems to be focused on procedures, regulations, and calculations related to tea trade and production.
#
# When considering similarity search for retrieval, the choice between sparse and dense vectors depends on the characteristics of the document collection and the desired retrieval performance.
#
# For the circular class of documents (e.g., TCEX-VI-8 2001 09 11.pdf, AL-MRL-07 2007 08 21 (10).pdf), which contain instructions and guidelines, I would recommend using sparse vectors. These documents typically have a structured format, with specific sections and keywords that are relevant to the topic. Sparse vectors are well-suited for capturing the significance of these keywords and can effectively represent the document's content. Additionally, sparse vectors can handle high-dimensional data and are often more interpretable than dense vectors.
#
# For the calculation-based documents (e.g., MF BL 79 I.pdf, MF BL 67 1985 12 31.pdf), which contain tables and mathematical formulas, I would suggest using dense vectors. These documents have a more complex structure, with numerical data and formulas that require a more nuanced representation. Dense vectors can capture the relationships between these numerical values and formulas, allowing for more accurate similarity search results.
#
# In general, if the document collection is primarily composed of unstructured or semi-structured text, sparse vectors might be a better choice. However, if the documents contain a significant amount of numerical or formula-based data, dense vectors could be more appropriate.
#
# It is essential to note that the choice between sparse and dense vectors ultimately depends on the specific requirements of the application and the characteristics of the document collection. Experimenting with both approaches and evaluating their performance using relevant metrics can help determine the most suitable method for the given use case.

# %% [markdown]
# # test 2: [BASELINE # 2][Top k similarity + keyword/entity extracted + currently flat vector RAG] [llama 3.1 8b instant - very relaible][KDB.ai] Create kdb.ai vector index and query the parsed documents

# %%
# lot's of unused imports, will sift thru tem later

# !pip install python-dotenv
# !pip install --upgrade  llama-index llama-index-core llama-index-readers-file llama-index-extractors-entity
# !pip install llama-index-vector-stores-lancedb
# !pip install llama_index.llms.groq llama-index-embeddings-fastembed
# Out:
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (1.0.1)
# Requirement already satisfied: llama-index in /usr/local/lib/python3.10/dist-packages (0.12.2)
# Requirement already satisfied: llama-index-core in /usr/local/lib/python3.10/dist-packages (0.12.2)
# Requirement already satisfied: llama-index-readers-file in /usr/local/lib/python3.10/dist-packages (0.4.0)
# Collecting llama-index-extractors-entity
#   Using cached llama_index_extractors_entity-0.3.0-py3-none-any.whl.metadata (730 bytes)
# Requirement already satisfied: llama-index-agent-openai<0.5.0,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from llama-index) (0.4.0)
# Requirement already satisfied: llama-index-cli<0.5.0,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from llama-index) (0.4.0)
# Requirement already satisfied: llama-index-embeddings-openai<0.4.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from llama-index) (0.3.1)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from llama-index) (0.6.3)
# Requirement already satisfied: llama-index-legacy<0.10.0,>=0.9.48 in /usr/local/lib/python3.10/dist-packages (from llama-index) (0.9.48.post4)
# Requirement already satisfied: llama-index-llms-openai<0.4.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from llama-index) (0.3.2)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.4.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from llama-index) (0.3.0)
# Requirement already satisfied: llama-index-program-openai<0.4.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from llama-index) (0.3.1)
# Requirement already satisfied: llama-index-question-gen-openai<0.4.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from llama-index) (0.3.0)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from llama-index) (0.4.0)
# Requirement already satisfied: nltk>3.8.1 in /usr/local/lib/python3.10/dist-packages (from llama-index) (3.9.1)
# Requirement already satisfied: PyYAML>=6.0.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /usr/local/lib/python3.10/dist-packages (from llama-index-core) (3.11.2)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.10/dist-packages (from llama-index-core) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-core) (1.2.15)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /usr/local/lib/python3.10/dist-packages (from llama-index-core) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core) (2024.10.0)
# Requirement already satisfied: httpx in /usr/local/lib/python3.10/dist-packages (from llama-index-core) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /usr/local/lib/python3.10/dist-packages (from llama-index-core) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core) (3.4.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from llama-index-core) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core) (10.4.0)
# Requirement already satisfied: pydantic<2.10.0,>=2.7.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core) (2.9.2)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-core) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core) (4.66.6)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core) (0.9.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from llama-index-core) (1.16.0)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-readers-file) (4.12.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from llama-index-readers-file) (2.2.2)
# Requirement already satisfied: pypdf<6.0.0,>=5.1.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-readers-file) (5.1.0)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in /usr/local/lib/python3.10/dist-packages (from llama-index-readers-file) (0.0.26)
# Collecting huggingface-hub<0.24.0 (from llama-index-extractors-entity)
#   Using cached huggingface_hub-0.23.5-py3-none-any.whl.metadata (12 kB)
# Collecting span-marker>=1.5.0 (from llama-index-extractors-entity)
#   Using cached span_marker-1.5.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (1.17.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (4.0.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file) (2.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<0.24.0->llama-index-extractors-entity) (3.16.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<0.24.0->llama-index-extractors-entity) (24.2)
# Requirement already satisfied: openai>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-agent-openai<0.5.0,>=0.4.0->llama-index) (1.54.4)
# Requirement already satisfied: llama-cloud>=0.1.5 in /usr/local/lib/python3.10/dist-packages (from llama-index-indices-managed-llama-cloud>=0.4.0->llama-index) (0.1.5)
# Requirement already satisfied: llama-parse>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-readers-llama-parse>=0.4.0->llama-index) (0.5.15)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>3.8.1->llama-index) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>3.8.1->llama-index) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>3.8.1->llama-index) (2024.9.11)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<2.10.0,>=2.7.0->llama-index-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<2.10.0,>=2.7.0->llama-index-core) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->llama-index-core) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->llama-index-core) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->llama-index-core) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->llama-index-core) (2024.8.30)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from span-marker>=1.5.0->llama-index-extractors-entity) (2.5.1+cu121)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (from span-marker>=1.5.0->llama-index-extractors-entity) (1.1.1)
# Requirement already satisfied: transformers>=4.19.0 in /usr/local/lib/python3.10/dist-packages (from span-marker>=1.5.0->llama-index-extractors-entity) (4.46.2)
# Collecting datasets>=2.14.0 (from span-marker>=1.5.0->llama-index-extractors-entity)
#   Using cached datasets-3.1.0-py3-none-any.whl.metadata (20 kB)
# Collecting evaluate (from span-marker>=1.5.0->llama-index-extractors-entity)
#   Using cached evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Collecting seqeval (from span-marker>=1.5.0->llama-index-extractors-entity)
#   Using cached seqeval-1.2.2.tar.gz (43 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from span-marker>=1.5.0->llama-index-extractors-entity) (3.1.4)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect>=0.8.0->llama-index-core) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json->llama-index-core) (3.23.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core) (1.0.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx->llama-index-core) (0.14.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index-readers-file) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index-readers-file) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index-readers-file) (2024.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.14.0->span-marker>=1.5.0->llama-index-extractors-entity) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets>=2.14.0->span-marker>=1.5.0->llama-index-extractors-entity)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting xxhash (from datasets>=2.14.0->span-marker>=1.5.0->llama-index-extractors-entity)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets>=2.14.0->span-marker>=1.5.0->llama-index-extractors-entity)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec>=2023.5.0 (from llama-index-core)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.14.0->llama-index-agent-openai<0.5.0,>=0.4.0->llama-index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.14.0->llama-index-agent-openai<0.5.0,>=0.4.0->llama-index) (0.7.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->llama-index-core) (1.2.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->llama-index-readers-file) (1.16.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.19.0->span-marker>=1.5.0->llama-index-extractors-entity) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.19.0->span-marker>=1.5.0->llama-index-extractors-entity) (0.20.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate->span-marker>=1.5.0->llama-index-extractors-entity) (5.9.5)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->span-marker>=1.5.0->llama-index-extractors-entity) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->span-marker>=1.5.0->llama-index-extractors-entity) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->span-marker>=1.5.0->llama-index-extractors-entity) (3.0.2)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.10/dist-packages (from seqeval->span-marker>=1.5.0->llama-index-extractors-entity) (1.5.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval->span-marker>=1.5.0->llama-index-extractors-entity) (1.13.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval->span-marker>=1.5.0->llama-index-extractors-entity) (3.5.0)
# Downloading llama_index_extractors_entity-0.3.0-py3-none-any.whl (3.4 kB)
# Downloading huggingface_hub-0.23.5-py3-none-any.whl (402 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 402.8/402.8 kB 8.1 MB/s eta 0:00:00
# Downloading span_marker-1.5.0-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.8 MB/s eta 0:00:00
# Downloading datasets-3.1.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 22.3 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 13.5 MB/s eta 0:00:00
# Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 5.6 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.6 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 7.7 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 12.1 MB/s eta 0:00:00
# Building wheels for collected packages: seqeval
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16161 sha256=7cfa67ec1fc7801adeb5066fca3078ecfdfc33ff6e2a175c491f0ced5ad43979
#   Stored in directory: /root/.cache/pip/wheels/1a/67/4a/ad4082dd7dfc30f2abfe4d80a2ed5926a506eb8a972b4767fa
# Successfully built seqeval
# Installing collected packages: xxhash, fsspec, dill, multiprocess, huggingface-hub, seqeval, datasets, evaluate, span-marker, llama-index-extractors-entity
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.26.2
#     Uninstalling huggingface-hub-0.26.2:
#       Successfully uninstalled huggingface-hub-0.26.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed datasets-3.1.0 dill-0.3.8 evaluate-0.4.3 fsspec-2024.9.0 huggingface-hub-0.23.5 llama-index-extractors-entity-0.3.0 multiprocess-0.70.16 seqeval-1.2.2 span-marker-1.5.0 xxhash-3.5.0
# Requirement already satisfied: llama-index-vector-stores-lancedb in /usr/local/lib/python3.10/dist-packages (0.3.0)
# Requirement already satisfied: lancedb>=0.13.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-vector-stores-lancedb) (0.16.0)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-vector-stores-lancedb) (0.12.2)
# Requirement already satisfied: tantivy in /usr/local/lib/python3.10/dist-packages (from llama-index-vector-stores-lancedb) (0.22.0)
# Requirement already satisfied: deprecation in /usr/local/lib/python3.10/dist-packages (from lancedb>=0.13.0->llama-index-vector-stores-lancedb) (2.1.0)
# Requirement already satisfied: nest-asyncio~=1.0 in /usr/local/lib/python3.10/dist-packages (from lancedb>=0.13.0->llama-index-vector-stores-lancedb) (1.6.0)
# Requirement already satisfied: pylance==0.19.2 in /usr/local/lib/python3.10/dist-packages (from lancedb>=0.13.0->llama-index-vector-stores-lancedb) (0.19.2)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.10/dist-packages (from lancedb>=0.13.0->llama-index-vector-stores-lancedb) (4.66.6)
# Requirement already satisfied: pydantic>=1.10 in /usr/local/lib/python3.10/dist-packages (from lancedb>=0.13.0->llama-index-vector-stores-lancedb) (2.9.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from lancedb>=0.13.0->llama-index-vector-stores-lancedb) (24.2)
# Requirement already satisfied: overrides>=0.7 in /usr/local/lib/python3.10/dist-packages (from lancedb>=0.13.0->llama-index-vector-stores-lancedb) (7.7.0)
# Requirement already satisfied: pyarrow>=12 in /usr/local/lib/python3.10/dist-packages (from pylance==0.19.2->lancedb>=0.13.0->llama-index-vector-stores-lancedb) (17.0.0)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.10/dist-packages (from pylance==0.19.2->lancedb>=0.13.0->llama-index-vector-stores-lancedb) (1.26.4)
# Requirement already satisfied: PyYAML>=6.0.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (3.11.2)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (1.2.15)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (2024.9.0)
# Requirement already satisfied: httpx in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (0.27.2)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (3.4.2)
# Requirement already satisfied: nltk>3.8.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (3.9.1)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (10.4.0)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (0.8.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (0.9.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (1.16.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (1.17.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (4.0.3)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (2024.9.11)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.10->lancedb>=0.13.0->llama-index-vector-stores-lancedb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.10->lancedb>=0.13.0->llama-index-vector-stores-lancedb) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (3.23.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (1.0.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (0.14.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-lancedb) (1.2.2)
# ERROR: Operation cancelled by user
# Requirement already satisfied: llama_index.llms.groq in /usr/local/lib/python3.10/dist-packages (0.3.0)
# Requirement already satisfied: llama-index-embeddings-fastembed in /usr/local/lib/python3.10/dist-packages (0.3.0)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.0 in /usr/local/lib/python3.10/dist-packages (from llama_index.llms.groq) (0.12.2)
# Requirement already satisfied: llama-index-llms-openai-like<0.4.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from llama_index.llms.groq) (0.3.0)
# Requirement already satisfied: fastembed>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from llama-index-embeddings-fastembed) (0.4.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.20 in /usr/local/lib/python3.10/dist-packages (from fastembed>=0.2.2->llama-index-embeddings-fastembed) (0.23.5)
# Requirement already satisfied: loguru<0.8.0,>=0.7.2 in /usr/local/lib/python3.10/dist-packages (from fastembed>=0.2.2->llama-index-embeddings-fastembed) (0.7.2)
# Requirement already satisfied: mmh3<5.0.0,>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from fastembed>=0.2.2->llama-index-embeddings-fastembed) (4.1.0)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.10/dist-packages (from fastembed>=0.2.2->llama-index-embeddings-fastembed) (1.26.4)
# Requirement already satisfied: onnx<2.0.0,>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from fastembed>=0.2.2->llama-index-embeddings-fastembed) (1.17.0)
# Requirement already satisfied: onnxruntime<1.20.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from fastembed>=0.2.2->llama-index-embeddings-fastembed) (1.19.2)
# Requirement already satisfied: pillow<11.0.0,>=10.3.0 in /usr/local/lib/python3.10/dist-packages (from fastembed>=0.2.2->llama-index-embeddings-fastembed) (10.4.0)
# Requirement already satisfied: py-rust-stemmers<0.2.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from fastembed>=0.2.2->llama-index-embeddings-fastembed) (0.1.3)
# Requirement already satisfied: requests<3.0,>=2.31 in /usr/local/lib/python3.10/dist-packages (from fastembed>=0.2.2->llama-index-embeddings-fastembed) (2.32.3)
# Requirement already satisfied: tokenizers<1.0,>=0.15 in /usr/local/lib/python3.10/dist-packages (from fastembed>=0.2.2->llama-index-embeddings-fastembed) (0.20.3)
# Requirement already satisfied: tqdm<5.0,>=4.66 in /usr/local/lib/python3.10/dist-packages (from fastembed>=0.2.2->llama-index-embeddings-fastembed) (4.66.6)
# Requirement already satisfied: PyYAML>=6.0.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (3.11.2)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (1.2.15)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (2024.9.0)
# Requirement already satisfied: httpx in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (3.4.2)
# Requirement already satisfied: nltk>3.8.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (3.9.1)
# Requirement already satisfied: pydantic<2.10.0,>=2.7.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (2.9.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (0.8.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (0.9.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (1.16.0)
# Requirement already satisfied: llama-index-llms-openai<0.4.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-llms-openai-like<0.4.0,>=0.3.0->llama_index.llms.groq) (0.3.2)
# Requirement already satisfied: transformers<5.0.0,>=4.37.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-llms-openai-like<0.4.0,>=0.3.0->llama_index.llms.groq) (4.46.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (1.17.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (4.0.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.20->fastembed>=0.2.2->llama-index-embeddings-fastembed) (3.16.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.20->fastembed>=0.2.2->llama-index-embeddings-fastembed) (24.2)
# Requirement already satisfied: openai<2.0.0,>=1.40.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-llms-openai<0.4.0,>=0.3.0->llama-index-llms-openai-like<0.4.0,>=0.3.0->llama_index.llms.groq) (1.54.4)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (2024.9.11)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from onnx<2.0.0,>=1.15.0->fastembed>=0.2.2->llama-index-embeddings-fastembed) (4.25.5)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.10/dist-packages (from onnxruntime<1.20.0,>=1.17.0->fastembed>=0.2.2->llama-index-embeddings-fastembed) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime<1.20.0,>=1.17.0->fastembed>=0.2.2->llama-index-embeddings-fastembed) (24.3.25)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime<1.20.0,>=1.17.0->fastembed>=0.2.2->llama-index-embeddings-fastembed) (1.13.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<2.10.0,>=2.7.0->llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<2.10.0,>=2.7.0->llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.31->fastembed>=0.2.2->llama-index-embeddings-fastembed) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.31->fastembed>=0.2.2->llama-index-embeddings-fastembed) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.31->fastembed>=0.2.2->llama-index-embeddings-fastembed) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.31->fastembed>=0.2.2->llama-index-embeddings-fastembed) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (3.1.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.37.0->llama-index-llms-openai-like<0.4.0,>=0.3.0->llama_index.llms.groq) (0.4.5)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (3.23.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (1.0.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (0.14.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.40.0->llama-index-llms-openai<0.4.0,>=0.3.0->llama-index-llms-openai-like<0.4.0,>=0.3.0->llama_index.llms.groq) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.40.0->llama-index-llms-openai<0.4.0,>=0.3.0->llama-index-llms-openai-like<0.4.0,>=0.3.0->llama_index.llms.groq) (0.7.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->llama-index-core<0.13.0,>=0.12.0->llama_index.llms.groq) (1.2.2)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.10/dist-packages (from coloredlogs->onnxruntime<1.20.0,>=1.17.0->fastembed>=0.2.2->llama-index-embeddings-fastembed) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime<1.20.0,>=1.17.0->fastembed>=0.2.2->llama-index-embeddings-fastembed) (1.3.0)

# %%
# !pip install llama-index-vector-stores-kdbai
# !pip install kdbai_client pandas
# Out:
# Collecting llama-index-vector-stores-kdbai
#   Downloading llama_index_vector_stores_kdbai-0.5.0-py3-none-any.whl.metadata (756 bytes)
# Collecting kdbai-client>=1.4.0 (from llama-index-vector-stores-kdbai)
#   Downloading kdbai_client-1.4.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-vector-stores-kdbai) (0.12.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from llama-index-vector-stores-kdbai) (2.2.2)
# Collecting pykx<3.0.0,>=2.1.1 (from llama-index-vector-stores-kdbai)
#   Downloading pykx-2.5.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from kdbai-client>=1.4.0->llama-index-vector-stores-kdbai) (24.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kdbai-client>=1.4.0->llama-index-vector-stores-kdbai) (2.32.3)
# Requirement already satisfied: PyYAML>=6.0.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-kdbai) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-kdbai) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-kdbai) (3.11.2)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-kdbai) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-kdbai) (1.2.15)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-kdbai) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-kdbai) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-kdbai) (2024.10.0)
# Requirement already satisfied: httpx in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-kdbai) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-kdbai) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-kdbai) (3.4.2)
# Requirement already satisfied: nltk>3.8.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-kdbai) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-kdbai) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-kdbai) (10.4.0)
# Requirement already satisfied: pydantic<2.10.0,>=2.7.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-kdbai) (2.9.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-kdbai) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-kdbai) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-kdbai) (4.66.6)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-kdbai) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-kdbai) (0.9.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-kdbai) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index-vector-stores-kdbai) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index-vector-stores-kdbai) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index-vector-stores-kdbai) (2024.2)
# Requirement already satisfied: toml~=0.10.2 in /usr/local/lib/python3.10/dist-packages (from pykx<3.0.0,>=2.1.1->llama-index-vector-stores-kdbai) (0.10.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-kdbai) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-kdbai) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-kdbai) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-kdbai) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-kdbai) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-kdbai) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-kdbai) (1.17.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-kdbai) (4.0.3)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-kdbai) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-kdbai) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-kdbai) (2024.9.11)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<2.10.0,>=2.7.0->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-kdbai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<2.10.0,>=2.7.0->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-kdbai) (2.23.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->llama-index-vector-stores-kdbai) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kdbai-client>=1.4.0->llama-index-vector-stores-kdbai) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kdbai-client>=1.4.0->llama-index-vector-stores-kdbai) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->kdbai-client>=1.4.0->llama-index-vector-stores-kdbai) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->kdbai-client>=1.4.0->llama-index-vector-stores-kdbai) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-kdbai) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-kdbai) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-kdbai) (3.23.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-kdbai) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-kdbai) (1.0.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-kdbai) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-kdbai) (0.14.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-kdbai) (1.2.2)
# Downloading llama_index_vector_stores_kdbai-0.5.0-py3-none-any.whl (4.6 kB)
# Downloading kdbai_client-1.4.0-py3-none-any.whl (30 kB)
# Downloading pykx-2.5.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 37.3 MB/s eta 0:00:00
# Installing collected packages: pykx, kdbai-client, llama-index-vector-stores-kdbai
# Successfully installed kdbai-client-1.4.0 llama-index-vector-stores-kdbai-0.5.0 pykx-2.5.5
# Requirement already satisfied: kdbai_client in /usr/local/lib/python3.10/dist-packages (1.4.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from kdbai_client) (24.2)
# Requirement already satisfied: pykx<3.0.0,>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from kdbai_client) (2.5.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kdbai_client) (2.32.3)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: toml~=0.10.2 in /usr/local/lib/python3.10/dist-packages (from pykx<3.0.0,>=2.1.1->kdbai_client) (0.10.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kdbai_client) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kdbai_client) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->kdbai_client) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->kdbai_client) (2024.8.30)

# %% [markdown]
# Until now, we were using tmporary lancedb vectordb, now using kdb.ai:

# %% [markdown]
# ## Define KDB.AI Session & Database
# KDB.AI comes in two offerings:
#
# KDB.AI Cloud - For experimenting with smaller generative AI projects with a vector database in our cloud.
# KDB.AI Server - For evaluating large scale generative AI applications on-premises or on your own cloud provider.
# Depending on which you use there will be different setup steps and connection details required.
#
# Option 1. KDB.AI Cloud
# To use KDB.AI Cloud, you will need two session details - a URL endpoint and an API key. To get these you can sign up for free here.
#
# You can connect to a KDB.AI Cloud session using kdbai.Session and passing the session URL endpoint and API key details from your KDB.AI Cloud portal.
#
# If the environment variables KDBAI_ENDPOINTS and KDBAI_API_KEY exist on your system containing your KDB.AI Cloud portal details, these variables will automatically be used to connect. If these do not exist, it will prompt you to enter your KDB.AI Cloud portal session URL endpoint and API key details.

# %% [markdown]
# ### KDB.AI Cloud

# %%
import os
import getpass

os.environ['KDBAI_ENDPOINT'] = getpass.getpass('Enter ykdb.ai endpoint: ')
os.environ['KDBAI_API_KEY'] = getpass.getpass('Enter your kdb.ai API Key: ')
# Out:
# Enter ykdb.ai endpoint: ··········
# Enter your kdb.ai API Key: ··········

# %%
#Set up KDB.AI endpoint and API key
KDBAI_ENDPOINT = (
    os.environ["KDBAI_ENDPOINT"]
    if "KDBAI_ENDPOINT" in os.environ
    else input("KDB.AI endpoint: ")
)
KDBAI_API_KEY = (
    os.environ["KDBAI_API_KEY"]
    if "KDBAI_API_KEY" in os.environ
    else getpass("KDB.AI API key: ")
)

# %%
# vector DB imports
import kdbai_client as kdbai

### Start Session with KDB.AI Cloud
session = kdbai.Session(api_key=KDBAI_API_KEY, endpoint=KDBAI_ENDPOINT)

# %% [markdown]
# ### Verify Defined Databases
#
# We can check our connection using the `session.databases()` function.
# This will return a list of all the databases we have defined in our vector database thus far.
# This should return a "default" database along with any other databases you have already created.

# %%
session.databases()
# Out:
# [KDBAI database "default", KDBAI database "srilanka_tea"]

# %% [markdown]
# ### Create a Database called "srilanka_tea"

# %%
# ensure no database called "srilanka_tea" exists
try:
    session.database("srilanka_tea").drop()
except kdbai.KDBAIException:
    pass

# %%
# Create the database
db = session.create_database("srilanka_tea")

# %% [markdown]
# ## Create Schema, Indexes and KDB.AI Table
#
# Now, let us define the schema that will be used to create the KDB.AI table.
#
# "ID" and "chunk" columns will hold the unique identifier and raw text chunk.
#
# sparse and dense columns will hold the respective sparse and dense vectors.

# %%
# Table - name & schema
table_name = "rag_baseline"

table_schema = [
        dict(name="document_id", type="bytes"),
        dict(name="text", type="bytes"),
        dict(name="embeddings", type="float32s"),
        # dict(name='metadata', type= "bytes"),  # Metadata as a string (can use JSON if needed)
        # dict(name="relationships", type="str"),
    ]

indexFlat = {
        "name": "flat_index",
        "type": "flat",
        "column": "embeddings",
        "params": {'dims': 384, 'metric': 'L2'},
    }

# %%
# List all of the tables in the db
db.tables
# Out:
# []

# %%
# First ensure the table does not already exist
try:
    db.table("rag_baseline").drop()
except kdbai.KDBAIException:
    pass

# %%
# Create table
table = db.create_table(table_name, table_schema, indexes=[indexFlat])

# %%
db.tables
# Out:
# [KDBAI table "rag_baseline"]

# %%
table.indexes
# Out:
# [{'name': 'flat_index',
#   'type': 'flat',
#   'column': 'embeddings',
#   'params': {'metric': 'L2', 'dims': 384}}]

# %% [markdown]
# ## Insert data into the KDB.AI Table

# %%
from llama_index.vector_stores.kdbai import KDBAIVectorStore
from llama_index.core import StorageContext
from llama_index.core import Settings
from llama_index.core.indices import VectorStoreIndex
from llama_index.core.node_parser import SentenceSplitter

# %%
# vector_store_lancedb = LanceDBVectorStore(uri="/tmp/lancedb_lamaindex")
# storage_context = StorageContext.from_defaults(vector_store=vector_store_lancedb)

# index = VectorStoreIndex(
#     nodes=nodes,
#     storage_context=storage_context,
#     embed_model=embed_model,
# )

# query_engine = index.as_query_engine(similarity_top_k=5, llm=llm)

# %%
# %%time

from llama_index.core.callbacks import LlamaDebugHandler
from llama_index.core.callbacks import CallbackManager


# Using the LlamaDebugHandler to print the trace of the sub questions captured by the SUB_QUESTION callback event type
llama_debug = LlamaDebugHandler(print_trace_on_end=True)
callback_manager = CallbackManager([llama_debug])
# Out:
# CPU times: user 64 µs, sys: 0 ns, total: 64 µs
# Wall time: 67.9 µs

# %%
import os
import getpass

# os.environ['LLAMA_CLOUD_API_KEY'] = getpass.getpass('Enter your LLamacloud API Key: ')
os.environ['GROQ_API_KEY'] = getpass.getpass('Enter your GROQ API Key: ')
# Out:
# Enter your GROQ API Key: ··········

# %%
from llama_index.llms.groq import Groq
from llama_index.embeddings.fastembed import FastEmbedEmbedding


embeddings_model = FastEmbedEmbedding(model_name="BAAI/bge-small-en-v1.5")
# llm_model = Groq(model="llama3-70b-8192", api_key=os.environ['GROQ_API_KEY'], temperature=0.0)
llm_model = Groq(model="llama-3.1-8b-instant", api_key=os.environ['GROQ_API_KEY'], temperature=0.0)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
# use keyword or entity for circuler class, and metadata-based indexing for regulation class,
# title extractor is redundant, arlready done, so is QA and summmary
# focus on keyword or entity

# %%
from llama_index.core.node_parser import MarkdownNodeParser
from llama_index.core.extractors import (
    SummaryExtractor,
    QuestionsAnsweredExtractor,
    TitleExtractor,
    KeywordExtractor,
)
from llama_index.extractors.entity import EntityExtractor

# transformations = [
#     SentenceSplitter(),
#     TitleExtractor(nodes=5),
#     QuestionsAnsweredExtractor(questions=3),
#     SummaryExtractor(summaries=["prev", "self"]),
#     KeywordExtractor(keywords=10),
#     EntityExtractor(prediction_threshold=0.5),
# ]


# Vector Store
text_store = KDBAIVectorStore(table=table)

# Storage context
storage_context = StorageContext.from_defaults(vector_store=text_store)
# title_extractor = TitleExtractor(llm = llm_model,  nodes=5)
# qa_extractor = QuestionsAnsweredExtractor(llm = llm_model, questions=3)
keyword_extractor = KeywordExtractor(llm = llm_model, keywords=5)
entity_extractor =  EntityExtractor(llm = llm_model, prediction_threshold=0.5)


# Settings
Settings.callback_manager = callback_manager
# Settings.transformations = [SentenceSplitter(chunk_size=500, chunk_overlap=0)]
Settings.transformations = [MarkdownNodeParser(),  keyword_extractor, entity_extractor]
Settings.embed_model = embeddings_model
Settings.llm = llm_model



# Vector Store Index
index = VectorStoreIndex.from_documents(
    documents,
    use_async=True,
    storage_context=storage_context,
)
# Out:
#   1%|▏         | 32/2523 [00:06<20:44,  2.00it/s]WARNING:llama_index.llms.openai.utils:Retrying llama_index.llms.openai.base.OpenAI._achat in 0.8757476500267178 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.1-8b-instant` in organization `org_01jcn2qw9aehtvc776pg7kbzv6` on requests per minute (RPM): Limit 30, Used 30, Requested 1. Please try again in 1.553s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': 'requests', 'code': 'rate_limit_exceeded'}}.
# WARNING:llama_index.llms.openai.utils:Retrying llama_index.llms.openai.base.OpenAI._achat in 0.6187796919283355 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.1-8b-instant` in organization `org_01jcn2qw9aehtvc776pg7kbzv6` on requests per minute (RPM): Limit 30, Used 30, Requested 1. Please try again in 1.515s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': 'requests', 'code': 'rate_limit_exceeded'}}.
# WARNING:llama_index.llms.openai.utils:Retrying llama_index.llms.openai.base.OpenAI._achat in 0.7637672165225865 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.1-8b-instant` in organization `org_01jcn2qw9aehtvc776pg7kbzv6` on requests per minute (RPM): Limit 30, Used 30, Requested 1. Please try again in 1.501s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': 'requests', 'code': 'rate_limit_exceeded'}}.
#   1%|▏         | 36/2523 [00:15<53:37,  1.29s/it]WARNING:llama_index.llms.openai.utils:Retrying llama_index.llms.openai.base.OpenAI._achat in 0.15026398423060017 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.1-8b-instant` in organization `org_01jcn2qw9aehtvc776pg7kbzv6` on requests per minute (RPM): Limit 30, Used 30, Requested 1. Please try again in 1.886s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': 'requests', 'code': 'rate_limit_exceeded'}}.
# WARNING:llama_index.llms.openai.utils:Retrying llama_index.llms.openai.base.OpenAI._achat in 0.8824832347142948 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.1-8b-instant` in organization `org_01jcn2qw9aehtvc776pg7kbzv6` on requests per minute (RPM): Limit 30, Used 30, Requested 1. Please try again in 1.995s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': 'requests', 'code': 'rate_limit_exceeded'}}.
#   2%|▏         | 39/2523 [00:21<1:12:02,  1.74s/it]
# **********
# Trace: index_construction
#     |_templating -> 6.3e-05 seconds
#     |_llm -> 0.68085 seconds
#     |_templating -> 0.000155 seconds
#     |_llm -> 0.648143 seconds
#     |_templating -> 5.7e-05 seconds
#     |_llm -> 0.517263 seconds
#     |_templating -> 6e-05 seconds
#     |_llm -> 0.518295 seconds
#     |_templating -> 2.9e-05 seconds
#     |_llm -> 0.150505 seconds
#     |_templating -> 2.8e-05 seconds
#     |_llm -> 0.164566 seconds
#     |_templating -> 2.9e-05 seconds
#     |_llm -> 0.162837 seconds
#     |_templating -> 4.1e-05 seconds
#     |_llm -> 0.170562 seconds
#     |_templating -> 6e-05 seconds
#     |_llm -> 0.18884 seconds
#     |_templating -> 2.9e-05 seconds
#     |_llm -> 0.17966 seconds
#     |_templating -> 2.9e-05 seconds
#     |_llm -> 0.190695 seconds
#     |_templating -> 2.7e-05 seconds
#     |_llm -> 0.177223 seconds
#     |_templating -> 3e-05 seconds
#     |_llm -> 0.178366 seconds
#     |_templating -> 2.7e-05 seconds
#     |_llm -> 0.228683 seconds
#     |_templating -> 3.7e-05 seconds
#     |_llm -> 0.132775 seconds
#     |_templating -> 2.9e-05 seconds
#     |_llm -> 0.164683 seconds
#     |_templating -> 4.1e-05 seconds
#     |_llm -> 0.160015 seconds
#     |_templating -> 2.9e-05 seconds
#     |_llm -> 0.194698 seconds
#     |_templating -> 4.7e-05 seconds
#     |_llm -> 0.139608 seconds
#     |_templating -> 3.9e-05 seconds
#     |_llm -> 0.177181 seconds
#     |_templating -> 3e-05 seconds
#     |_llm -> 0.162169 seconds
#     |_templating -> 2.8e-05 seconds
#     |_llm -> 0.169172 seconds
#     |_templating -> 3.2e-05 seconds
#     |_llm -> 0.188229 seconds
#     |_templating -> 3.9e-05 seconds
#     |_llm -> 0.144307 seconds
#     |_templating -> 3.4e-05 seconds
#     |_llm -> 0.174878 seconds
#     |_templating -> 2.7e-05 seconds
#     |_llm -> 0.18595 seconds
#     |_templating -> 3e-05 seconds
#     |_llm -> 0.145125 seconds
#     |_templating -> 3e-05 seconds
#     |_llm -> 0.195917 seconds
#     |_templating -> 2.9e-05 seconds
#     |_llm -> 0.141701 seconds
#     |_templating -> 3e-05 seconds
#     |_llm -> 0.831853 seconds
#     |_templating -> 2.8e-05 seconds
#     |_llm -> 2.230329 seconds
#     |_templating -> 4.3e-05 seconds
#     |_llm -> 19.752028 seconds
#     |_templating -> 5e-05 seconds
#     |_llm -> 10.97036 seconds
#     |_templating -> 3.4e-05 seconds
#     |_llm -> 12.466817 seconds
#     |_templating -> 2.9e-05 seconds
#     |_llm -> 2.242976 seconds
#     |_templating -> 3.4e-05 seconds
#     |_llm -> 2.240371 seconds
#     |_templating -> 3e-05 seconds
#     |_llm -> 2.272612 seconds
#     |_templating -> 4.3e-05 seconds
#     |_llm -> 0.0 seconds
#     |_templating -> 4.6e-05 seconds
#     |_llm -> 4.319753 seconds
#     |_templating -> 2.9e-05 seconds
#     |_llm -> 4.310151 seconds
#     |_templating -> 2.8e-05 seconds
#     |_llm -> 4.321596 seconds
#     |_templating -> 3e-05 seconds
#     |_llm -> 0.0 seconds
#     |_templating -> 3e-05 seconds
#     |_llm -> 0.0 seconds
#     |_exception -> 0.0 seconds
#     |_templating -> 2.4e-05 seconds
#     |_llm -> 0.0 seconds
# **********
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# <ipython-input-57-78fcfda9fe02> in <cell line: 41>()
#      39
#      40 # Vector Store Index
# ---> 41 index = VectorStoreIndex.from_documents(
#      42     documents,
#      43     use_async=True,
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/base.py in from_documents(cls, documents, storage_context, show_progress, callback_manager, transformations, **kwargs)
#     110                 docstore.set_document_hash(doc.get_doc_id(), doc.hash)
#     111
# --> 112             nodes = run_transformations(
#     113                 documents,  # type: ignore
#     114                 transformations,
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/ingestion/pipeline.py in run_transformations(nodes, transformations, in_place, cache, cache_collection, **kwargs)
#      98                 cache.put(hash, nodes, collection=cache_collection)
#      99         else:
# --> 100             nodes = transform(nodes, **kwargs)
#     101
#     102     return nodes
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in wrapper(func, instance, args, kwargs)
#     319
#     320             try:
# --> 321                 result = func(*args, **kwargs)
#     322                 if isinstance(result, asyncio.Future):
#     323                     # If the result is a Future, wrap it
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/extractors/interface.py in __call__(self, nodes, **kwargs)
#     158             nodes (List[BaseNode]): nodes to post-process
#     159         """
# --> 160         return self.process_nodes(nodes, **kwargs)
#     161
#     162     async def acall(self, nodes: Sequence[BaseNode], **kwargs: Any) -> List[BaseNode]:
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/extractors/interface.py in process_nodes(self, nodes, excluded_embed_metadata_keys, excluded_llm_metadata_keys, **kwargs)
#     141         **kwargs: Any,
#     142     ) -> List[BaseNode]:
# --> 143         return asyncio_run(
#     144             self.aprocess_nodes(
#     145                 nodes,
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/async_utils.py in asyncio_run(coro)
#      31
#      32         # If we're here, there's an existing loop but it's not running
# ---> 33         return loop.run_until_complete(coro)
#      34
#      35     except RuntimeError as e:
#
# /usr/local/lib/python3.10/dist-packages/nest_asyncio.py in run_until_complete(self, future)
#      96                 raise RuntimeError(
#      97                     'Event loop stopped before Future completed.')
# ---> 98             return f.result()
#      99
#     100     def _run_once(self):
#
# /usr/lib/python3.10/asyncio/futures.py in result(self)
#     199         self.__log_traceback = False
#     200         if self._exception is not None:
# --> 201             raise self._exception.with_traceback(self._exception_tb)
#     202         return self._result
#     203
#
# /usr/lib/python3.10/asyncio/tasks.py in __step(***failed resolving arguments***)
#     230                 # We use the `send` method directly, because coroutines
#     231                 # don't have `__iter__` and `__next__` methods.
# --> 232                 result = coro.send(None)
#     233             else:
#     234                 result = coro.throw(exc)
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/extractors/interface.py in aprocess_nodes(self, nodes, excluded_embed_metadata_keys, excluded_llm_metadata_keys, **kwargs)
#     119             new_nodes = [deepcopy(node) for node in nodes]
#     120
# --> 121         cur_metadata_list = await self.aextract(new_nodes)
#     122         for idx, node in enumerate(new_nodes):
#     123             node.metadata.update(cur_metadata_list[idx])
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in async_wrapper(func, instance, args, kwargs)
#     365             )
#     366             try:
# --> 367                 result = await func(*args, **kwargs)
#     368             except BaseException as e:
#     369                 self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/extractors/metadata_extractors.py in aextract(self, nodes)
#     229             keyword_jobs.append(self._aextract_keywords_from_node(node))
#     230
# --> 231         metadata_list: List[Dict] = await run_jobs(
#     232             keyword_jobs, show_progress=self.show_progress, workers=self.num_workers
#     233         )
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in async_wrapper(func, instance, args, kwargs)
#     365             )
#     366             try:
# --> 367                 result = await func(*args, **kwargs)
#     368             except BaseException as e:
#     369                 self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/async_utils.py in run_jobs(jobs, show_progress, workers, desc)
#     144         from tqdm.asyncio import tqdm_asyncio
#     145
# --> 146         results = await tqdm_asyncio.gather(*pool_jobs, desc=desc)
#     147     else:
#     148         results = await asyncio.gather(*pool_jobs)
#
# /usr/local/lib/python3.10/dist-packages/tqdm/asyncio.py in gather(cls, loop, timeout, total, *fs, **tqdm_kwargs)
#      77
#      78         ifs = [wrap_awaitable(i, f) for i, f in enumerate(fs)]
# ---> 79         res = [await f for f in cls.as_completed(ifs, loop=loop, timeout=timeout,
#      80                                                  total=total, **tqdm_kwargs)]
#      81         return [i for _, i in sorted(res)]
#
# /usr/local/lib/python3.10/dist-packages/tqdm/asyncio.py in <listcomp>(.0)
#      77
#      78         ifs = [wrap_awaitable(i, f) for i, f in enumerate(fs)]
# ---> 79         res = [await f for f in cls.as_completed(ifs, loop=loop, timeout=timeout,
#      80                                                  total=total, **tqdm_kwargs)]
#      81         return [i for _, i in sorted(res)]
#
# /usr/lib/python3.10/asyncio/tasks.py in _wait_for_one()
#     569             # Dummy value from _on_timeout().
#     570             raise exceptions.TimeoutError
# --> 571         return f.result()  # May raise f.exception().
#     572
#     573     for f in todo:
#
# /usr/lib/python3.10/asyncio/futures.py in result(self)
#     199         self.__log_traceback = False
#     200         if self._exception is not None:
# --> 201             raise self._exception.with_traceback(self._exception_tb)
#     202         return self._result
#     203
#
# /usr/lib/python3.10/asyncio/tasks.py in __step(***failed resolving arguments***)
#     230                 # We use the `send` method directly, because coroutines
#     231                 # don't have `__iter__` and `__next__` methods.
# --> 232                 result = coro.send(None)
#     233             else:
#     234                 result = coro.throw(exc)
#
# /usr/local/lib/python3.10/dist-packages/tqdm/asyncio.py in wrap_awaitable(i, f)
#      74         """
#      75         async def wrap_awaitable(i, f):
# ---> 76             return i, await f
#      77
#      78         ifs = [wrap_awaitable(i, f) for i, f in enumerate(fs)]
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in async_wrapper(func, instance, args, kwargs)
#     365             )
#     366             try:
# --> 367                 result = await func(*args, **kwargs)
#     368             except BaseException as e:
#     369                 self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/async_utils.py in worker(job)
#     137     async def worker(job: Coroutine) -> Any:
#     138         async with semaphore:
# --> 139             return await job
#     140
#     141     pool_jobs = [worker(job) for job in jobs]
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/extractors/metadata_extractors.py in _aextract_keywords_from_node(self, node)
#     216
#     217         context_str = node.get_content(metadata_mode=self.metadata_mode)
# --> 218         keywords = await self.llm.apredict(
#     219             PromptTemplate(template=self.prompt_template),
#     220             keywords=self.keywords,
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in async_wrapper(func, instance, args, kwargs)
#     365             )
#     366             try:
# --> 367                 result = await func(*args, **kwargs)
#     368             except BaseException as e:
#     369                 self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py in apredict(self, prompt, **prompt_args)
#     683         if self.metadata.is_chat_model:
#     684             messages = self._get_messages(prompt, **prompt_args)
# --> 685             chat_response = await self.achat(messages)
#     686             output = chat_response.message.content or ""
#     687         else:
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in async_wrapper(func, instance, args, kwargs)
#     365             )
#     366             try:
# --> 367                 result = await func(*args, **kwargs)
#     368             except BaseException as e:
#     369                 self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# /usr/local/lib/python3.10/dist-packages/llama_index/llms/openai_like/base.py in achat(self, messages, **kwargs)
#     156             return completion_response_to_chat_response(completion_response)
#     157
# --> 158         return await super().achat(messages, **kwargs)
#     159
#     160     async def astream_chat(
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in async_wrapper(func, instance, args, kwargs)
#     365             )
#     366             try:
# --> 367                 result = await func(*args, **kwargs)
#     368             except BaseException as e:
#     369                 self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/llms/callbacks.py in wrapped_async_llm_chat(_self, messages, **kwargs)
#      73                 )
#      74                 try:
# ---> 75                     f_return_val = await f(_self, messages, **kwargs)
#      76                 except BaseException as e:
#      77                     callback_manager.on_event_end(
#
# /usr/local/lib/python3.10/dist-packages/llama_index/llms/openai/base.py in achat(self, messages, **kwargs)
#     625         else:
#     626             achat_fn = acompletion_to_chat_decorator(self._acomplete)
# --> 627         return await achat_fn(messages, **kwargs)
#     628
#     629     @llm_chat_callback()
#
# /usr/local/lib/python3.10/dist-packages/tenacity/asyncio/__init__.py in async_wrapped(*args, **kwargs)
#     187             copy = self.copy()
#     188             async_wrapped.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 189             return await copy(fn, *args, **kwargs)
#     190
#     191         # Preserve attributes
#
# /usr/local/lib/python3.10/dist-packages/tenacity/asyncio/__init__.py in __call__(self, fn, *args, **kwargs)
#     109         retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     110         while True:
# --> 111             do = await self.iter(retry_state=retry_state)
#     112             if isinstance(do, DoAttempt):
#     113                 try:
#
# /usr/local/lib/python3.10/dist-packages/tenacity/asyncio/__init__.py in iter(self, retry_state)
#     151         result = None
#     152         for action in self.iter_state.actions:
# --> 153             result = await action(retry_state)
#     154         return result
#     155
#
# /usr/local/lib/python3.10/dist-packages/tenacity/_utils.py in inner(*args, **kwargs)
#      97
#      98     async def inner(*args: typing.Any, **kwargs: typing.Any) -> typing.Any:
# ---> 99         return call(*args, **kwargs)
#     100
#     101     return inner
#
# /usr/local/lib/python3.10/dist-packages/tenacity/__init__.py in exc_check(rs)
#     416                 retry_exc = self.retry_error_cls(fut)
#     417                 if self.reraise:
# --> 418                     raise retry_exc.reraise()
#     419                 raise retry_exc from fut.exception()
#     420
#
# /usr/local/lib/python3.10/dist-packages/tenacity/__init__.py in reraise(self)
#     183     def reraise(self) -> t.NoReturn:
#     184         if self.last_attempt.failed:
# --> 185             raise self.last_attempt.result()
#     186         raise self
#     187
#
# /usr/lib/python3.10/concurrent/futures/_base.py in result(self, timeout)
#     449                     raise CancelledError()
#     450                 elif self._state == FINISHED:
# --> 451                     return self.__get_result()
#     452
#     453                 self._condition.wait(timeout)
#
# /usr/lib/python3.10/concurrent/futures/_base.py in __get_result(self)
#     401         if self._exception:
#     402             try:
# --> 403                 raise self._exception
#     404             finally:
#     405                 # Break a reference cycle with the exception in self._exception
#
# /usr/local/lib/python3.10/dist-packages/tenacity/asyncio/__init__.py in __call__(self, fn, *args, **kwargs)
#     112             if isinstance(do, DoAttempt):
#     113                 try:
# --> 114                     result = await fn(*args, **kwargs)
#     115                 except BaseException:  # noqa: B902
#     116                     retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# /usr/local/lib/python3.10/dist-packages/llama_index/llms/openai/base.py in _achat(self, messages, **kwargs)
#     672
#     673         if self.reuse_client:
# --> 674             response = await aclient.chat.completions.create(
#     675                 messages=message_dicts, stream=False, **self._get_model_kwargs(**kwargs)
#     676             )
#
# /usr/local/lib/python3.10/dist-packages/openai/resources/chat/completions.py in create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#    1659     ) -> ChatCompletion | AsyncStream[ChatCompletionChunk]:
#    1660         validate_response_format(response_format)
# -> 1661         return await self._post(
#    1662             "/chat/completions",
#    1663             body=await async_maybe_transform(
#
# /usr/local/lib/python3.10/dist-packages/openai/_base_client.py in post(self, path, cast_to, body, files, options, stream, stream_cls)
#    1837             method="post", url=path, json_data=body, files=await async_to_httpx_files(files), **options
#    1838         )
# -> 1839         return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#    1840
#    1841     async def patch(
#
# /usr/local/lib/python3.10/dist-packages/openai/_base_client.py in request(self, cast_to, options, stream, stream_cls, remaining_retries)
#    1531             retries_taken = 0
#    1532
# -> 1533         return await self._request(
#    1534             cast_to=cast_to,
#    1535             options=options,
#
# /usr/local/lib/python3.10/dist-packages/openai/_base_client.py in _request(self, cast_to, options, stream, stream_cls, retries_taken)
#    1617             if remaining_retries > 0 and self._should_retry(err.response):
#    1618                 await err.response.aclose()
# -> 1619                 return await self._retry_request(
#    1620                     input_options,
#    1621                     cast_to,
#
# /usr/local/lib/python3.10/dist-packages/openai/_base_client.py in _retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1664         await anyio.sleep(timeout)
#    1665
# -> 1666         return await self._request(
#    1667             options=options,
#    1668             cast_to=cast_to,
#
# /usr/local/lib/python3.10/dist-packages/openai/_base_client.py in _request(self, cast_to, options, stream, stream_cls, retries_taken)
#    1617             if remaining_retries > 0 and self._should_retry(err.response):
#    1618                 await err.response.aclose()
# -> 1619                 return await self._retry_request(
#    1620                     input_options,
#    1621                     cast_to,
#
# /usr/local/lib/python3.10/dist-packages/openai/_base_client.py in _retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1664         await anyio.sleep(timeout)
#    1665
# -> 1666         return await self._request(
#    1667             options=options,
#    1668             cast_to=cast_to,
#
# /usr/local/lib/python3.10/dist-packages/openai/_base_client.py in _request(self, cast_to, options, stream, stream_cls, retries_taken)
#    1617             if remaining_retries > 0 and self._should_retry(err.response):
#    1618                 await err.response.aclose()
# -> 1619                 return await self._retry_request(
#    1620                     input_options,
#    1621                     cast_to,
#
# /usr/local/lib/python3.10/dist-packages/openai/_base_client.py in _retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1664         await anyio.sleep(timeout)
#    1665
# -> 1666         return await self._request(
#    1667             options=options,
#    1668             cast_to=cast_to,
#
# /usr/local/lib/python3.10/dist-packages/openai/_base_client.py in _request(self, cast_to, options, stream, stream_cls, retries_taken)
#    1632
#    1633             log.debug("Re-raising status error")
# -> 1634             raise self._make_status_error_from_response(err.response) from None
#    1635
#    1636         return await self._process_response(
#
# RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.1-8b-instant` in organization `org_01jcn2qw9aehtvc776pg7kbzv6` on requests per minute (RPM): Limit 30, Used 30, Requested 1. Please try again in 1.805s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': 'requests', 'code': 'rate_limit_exceeded'}}

# %%
from llama_index.core.node_parser import MarkdownNodeParser
from llama_index.core.extractors import (
    SummaryExtractor,
    QuestionsAnsweredExtractor,
    TitleExtractor,
    KeywordExtractor,
)
from llama_index.extractors.entity import EntityExtractor
import time
from itertools import islice

# Function to chunk documents

def chunked_iterable(iterable, size):
    """Splits an iterable into chunks of specified size."""
    it = iter(iterable)
    return iter(lambda: list(islice(it, size)), [])

# Function for exponential backoff

def exponential_backoff(func, *args, max_retries=5, **kwargs):
    retries = 0
    while retries < max_retries:
        try:
            return func(*args, **kwargs)
        except RateLimitError as e:
            retry_after = 2 ** retries  # Exponential backoff
            print(f"Rate limit exceeded. Retrying in {retry_after} seconds...")
            time.sleep(retry_after)
            retries += 1
    raise Exception("Max retries reached")

# Vector Store
text_store = KDBAIVectorStore(table=table)

# Storage context
storage_context = StorageContext.from_defaults(vector_store=text_store)

# Optimized extractors
keyword_extractor = KeywordExtractor(llm=llm_model, keywords=3)  # Reduced keyword count
entity_extractor = EntityExtractor(llm=llm_model, prediction_threshold=0.5)

# Settings
Settings.callback_manager = callback_manager
Settings.transformations = [MarkdownNodeParser(), keyword_extractor, entity_extractor]
Settings.embed_model = embeddings_model
Settings.llm = llm_model

# Batch processing documents with exponential backoff
for chunk in chunked_iterable(documents, 10):  # Batch size of 10
    try:
        index = exponential_backoff(VectorStoreIndex.from_documents, chunk, use_async=True, storage_context=storage_context)
    except Exception as e:
        print(f"Error occurred while processing documents: {e}")
# Out:
# config.json:   0%|          | 0.00/5.08k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/712M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# The new embeddings will be initialized from a multivariate normal distribution that has old embeddings' mean and covariance. As described in this article: https://nlp.stanford.edu/~johnhew/vocab-expansion.html. To disable this, use `mean_resizing=False`
# 100%|██████████| 10/10 [00:00<00:00, 12.44it/s]
# Extracting entities:   0%|          | 0/10 [00:00<?, ?it/s]
# **********
# Trace: index_construction
#     |_templating -> 0.000107 seconds
#     |_llm -> 0.450699 seconds
#     |_templating -> 9.7e-05 seconds
#     |_llm -> 0.29177 seconds
#     |_templating -> 4.9e-05 seconds
#     |_llm -> 0.251612 seconds
#     |_templating -> 4.6e-05 seconds
#     |_llm -> 0.26235 seconds
#     |_templating -> 4.9e-05 seconds
#     |_llm -> 0.180205 seconds
#     |_templating -> 4.6e-05 seconds
#     |_llm -> 0.17886 seconds
#     |_templating -> 4.8e-05 seconds
#     |_llm -> 0.181498 seconds
#     |_templating -> 3.9e-05 seconds
#     |_llm -> 0.164234 seconds
#     |_templating -> 3.7e-05 seconds
#     |_llm -> 0.155239 seconds
#     |_templating -> 4.1e-05 seconds
#     |_llm -> 0.196986 seconds
#     |_exception -> 0.0 seconds
# **********
# Error occurred while processing documents: name 'RateLimitError' is not defined
# 100%|██████████| 10/10 [00:00<00:00, 15.50it/s]
# Extracting entities:   0%|          | 0/10 [00:00<?, ?it/s]
# **********
# Trace: index_construction
#     |_templating -> 4.5e-05 seconds
#     |_llm -> 0.230356 seconds
#     |_templating -> 4.8e-05 seconds
#     |_llm -> 0.193828 seconds
#     |_templating -> 4.9e-05 seconds
#     |_llm -> 0.208498 seconds
#     |_templating -> 7.1e-05 seconds
#     |_llm -> 0.228595 seconds
#     |_templating -> 3.8e-05 seconds
#     |_llm -> 0.215633 seconds
#     |_templating -> 4.1e-05 seconds
#     |_llm -> 0.215841 seconds
#     |_templating -> 3.9e-05 seconds
#     |_llm -> 0.220492 seconds
#     |_templating -> 5.3e-05 seconds
#     |_llm -> 0.203933 seconds
#     |_templating -> 4.3e-05 seconds
#     |_llm -> 0.211824 seconds
#     |_templating -> 4.5e-05 seconds
#     |_llm -> 0.150964 seconds
#     |_exception -> 0.0 seconds
# **********
# Error occurred while processing documents: name 'RateLimitError' is not defined
# 100%|██████████| 10/10 [00:00<00:00, 13.67it/s]
# Extracting entities:   0%|          | 0/10 [00:00<?, ?it/s]
# **********
# Trace: index_construction
#     |_templating -> 5.1e-05 seconds
#     |_llm -> 0.253003 seconds
#     |_templating -> 5.2e-05 seconds
#     |_llm -> 0.197099 seconds
#     |_templating -> 5.3e-05 seconds
#     |_llm -> 0.190914 seconds
#     |_templating -> 0.000268 seconds
#     |_llm -> 0.20132 seconds
#     |_templating -> 4.2e-05 seconds
#     |_llm -> 0.179757 seconds
#     |_templating -> 3e-05 seconds
#     |_llm -> 0.17942 seconds
#     |_templating -> 4.8e-05 seconds
#     |_llm -> 0.331309 seconds
#     |_templating -> 3.2e-05 seconds
#     |_llm -> 0.357003 seconds
#     |_templating -> 3.3e-05 seconds
#     |_llm -> 0.300163 seconds
#     |_templating -> 4.3e-05 seconds
#     |_llm -> 0.302455 seconds
#     |_exception -> 0.0 seconds
# **********
# Error occurred while processing documents: name 'RateLimitError' is not defined
#  50%|█████     | 5/10 [00:10<00:10,  2.15s/it]WARNING:llama_index.llms.openai.utils:Retrying llama_index.llms.openai.base.OpenAI._achat in 0.12839809322882245 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.1-8b-instant` in organization `org_01jd32h73be2wby2n3gxm4846p` on requests per minute (RPM): Limit 30, Used 30, Requested 1. Please try again in 1.999s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': 'requests', 'code': 'rate_limit_exceeded'}}.
# 100%|██████████| 10/10 [00:21<00:00,  2.14s/it]
# Extracting entities:   0%|          | 0/10 [00:00<?, ?it/s]
# **********
# Trace: index_construction
#     |_templating -> 5.4e-05 seconds
#     |_llm -> 2.292928 seconds
#     |_templating -> 5.1e-05 seconds
#     |_llm -> 8.524498 seconds
#     |_templating -> 5.7e-05 seconds
#     |_llm -> 4.383441 seconds
#     |_templating -> 5.2e-05 seconds
#     |_llm -> 4.377863 seconds
#     |_templating -> 3.3e-05 seconds
#     |_llm -> 8.482603 seconds
#     |_templating -> 3e-05 seconds
#     |_llm -> 8.485774 seconds
#     |_templating -> 5.2e-05 seconds
#     |_llm -> 16.995612 seconds
#     |_templating -> 2.6e-05 seconds
#     |_llm -> 4.352706 seconds
#     |_templating -> 3.6e-05 seconds
#     |_llm -> 8.498911 seconds
#     |_templating -> 3.5e-05 seconds
#     |_llm -> 4.250284 seconds
#     |_exception -> 0.0 seconds
# **********
# Error occurred while processing documents: name 'RateLimitError' is not defined
#  20%|██        | 2/10 [00:04<00:17,  2.18s/it]WARNING:llama_index.llms.openai.utils:Retrying llama_index.llms.openai.base.OpenAI._achat in 0.3364841829252305 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.1-8b-instant` in organization `org_01jd32h73be2wby2n3gxm4846p` on requests per minute (RPM): Limit 30, Used 30, Requested 1. Please try again in 1.963s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': 'requests', 'code': 'rate_limit_exceeded'}}.
#  30%|███       | 3/10 [00:06<00:15,  2.16s/it]WARNING:llama_index.llms.openai.utils:Retrying llama_index.llms.openai.base.OpenAI._achat in 0.07451533415321476 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.1-8b-instant` in organization `org_01jd32h73be2wby2n3gxm4846p` on requests per minute (RPM): Limit 30, Used 30, Requested 1. Please try again in 1.997s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': 'requests', 'code': 'rate_limit_exceeded'}}.
#  60%|██████    | 6/10 [00:13<00:08,  2.19s/it]WARNING:llama_index.llms.openai.utils:Retrying llama_index.llms.openai.base.OpenAI._achat in 0.06845669274018729 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.1-8b-instant` in organization `org_01jd32h73be2wby2n3gxm4846p` on requests per minute (RPM): Limit 30, Used 30, Requested 1. Please try again in 1.828s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': 'requests', 'code': 'rate_limit_exceeded'}}.
# WARNING:llama_index.llms.openai.utils:Retrying llama_index.llms.openai.base.OpenAI._achat in 0.5086771413643263 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.1-8b-instant` in organization `org_01jd32h73be2wby2n3gxm4846p` on requests per minute (RPM): Limit 30, Used 30, Requested 1. Please try again in 1.975s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': 'requests', 'code': 'rate_limit_exceeded'}}.
#  70%|███████   | 7/10 [00:15<00:06,  2.16s/it]

# %% [markdown]
# make the above pipeline async if possible

# %%
# from llama_index.core import Document
# from llama_index.embeddings.openai import OpenAIEmbedding
# from llama_index.core.node_parser import SentenceSplitter
# from llama_index.core.extractors import TitleExtractor
# from llama_index.core.ingestion import IngestionPipeline, IngestionCache
# from llama_index.vector_stores.qdrant import QdrantVectorStore

# import qdrant_client

# # Initialize the Qdrant client and vector store
# client = qdrant_client.QdrantClient(location=":memory:")
# vector_store = QdrantVectorStore(client=client, collection_name="test_store")

# # Create the pipeline with transformations
# pipeline = IngestionPipeline(
#     transformations=[
#         SentenceSplitter(chunk_size=25, chunk_overlap=0),  # Split the document into smaller chunks
#         TitleExtractor(),  # Extract the document title
#         OpenAIEmbedding(),  # Apply OpenAI embeddings to document chunks
#     ],
#     vector_store=vector_store  # Optionally, store results in a vector store
# )

# # Run the pipeline on a list of documents (in this case, just an example document)
# documents = [Document.example()]
# pipeline.run(documents=documents)


# # Connect to Qdrant and initialize the vector store
# client = qdrant_client.QdrantClient(location=":memory:")
# vector_store = QdrantVectorStore(client=client, collection_name="documents_collection")

# # Create a pipeline that uses the vector store
# pipeline = IngestionPipeline(
#     transformations=[
#         SentenceSplitter(chunk_size=25, chunk_overlap=0),
#         TitleExtractor(),
#         OpenAIEmbedding(),
#     ],
#     vector_store=vector_store,
# )

# # Run the pipeline
# pipeline.run(documents=documents)


# # Save the cache
# pipeline.persist("./pipeline_storage")

# # Load the cache and restore the pipeline state
# new_pipeline = IngestionPipeline(
#     transformations=[
#         SentenceSplitter(chunk_size=25, chunk_overlap=0),
#         TitleExtractor(),
#     ],
# )
# new_pipeline.load("./pipeline_storage")

# # Running the pipeline now will be faster due to the cache
# nodes = new_pipeline.run(documents=documents)


# # Asynchronous document processing
# nodes = await pipeline.arun(documents=documents)

# # Run the pipeline with parallel processing using multiprocessing
# pipeline.run(documents=documents, num_workers=4)


# from llama_index.core.storage.docstore import SimpleDocumentStore

# # Initialize the document store
# docstore = SimpleDocumentStore()

# # Create a pipeline that uses the document store
# pipeline = IngestionPipeline(
#     transformations=[
#         SentenceSplitter(chunk_size=25, chunk_overlap=0),
#         TitleExtractor(),
#         OpenAIEmbedding(),
#     ],
#     docstore=docstore,
# )

# # Run the pipeline
# pipeline.run(documents=documents)


# import asyncio
# from llama_index.core import Document
# from llama_index.embeddings.openai import OpenAIEmbedding
# from llama_index.core.node_parser import SentenceSplitter
# from llama_index.core.extractors import TitleExtractor
# from llama_index.core.ingestion import IngestionPipeline
# from llama_index.vector_stores.qdrant import QdrantVectorStore
# import qdrant_client

# # Define the async processing pipeline
# async def async_pipeline(documents):
#     client = qdrant_client.QdrantClient(location=":memory:")
#     vector_store = QdrantVectorStore(client=client, collection_name="test_collection")

#     pipeline = IngestionPipeline(
#         transformations=[
#             SentenceSplitter(chunk_size=25, chunk_overlap=0),
#             TitleExtractor(),
#             OpenAIEmbedding(),
#         ],
#         vector_store=vector_store
#     )

#     # Run the pipeline asynchronously
#     nodes = await pipeline.arun(documents=documents)
#     return nodes

# # Example document list
# documents = [Document.example()]

# # Run the pipeline and await the result
# result = asyncio.run(async_pipeline(documents))

# # Print the processed nodes
# print(result)

# %% [markdown]
# ## Index as Vector Query Engine

# %% [markdown]
# define better query engine that uses metadata returned: https://docs.llamaindex.ai/en/stable/examples/metadata_extraction/MetadataExtraction_LLMSurvey/

# %% [markdown]
# ### added top k similarity = 5 retrieval + [more to add]: keyword based querying, also try with both desnse and sparse vector, add query router for multiple classes and add subquery option to break longer queries into shorter ones, try cohere reranker
#
#
# ## try ReAct to work with all of this

# %%
# Vector query engine
vector_query_engine = index.as_query_engine(
                                similarity_top_k=5,
                                llm=llm,
                                vector_store_kwargs={
                                    "index" : "flat",
                                },
                            )

# %%
query = "sumarize all regulatory changes that happened in 2022 related to tea"
response_1 = vector_query_engine.query(query)
print("\n**LlamaParse+ Lamaindex**")
print(response_1)

# %%
# %%time

# # Using gpt-4o-mini, the 128k tokens context size can take 100 pages.
# K = 5

# query_engine = index.as_query_engine(
#                 similarity_top_k=K,
#                 vector_store_kwargs={
#                         "index" : "flat_index",
#                         "filter" : [["<", "publication_date", datetime.date(2008,9,15)]],
#                         "sort_columns" : "publication_date"
#                         }
#         )

# %%
# %%time

# # Using gpt-4o-mini, the 128k tokens context size can take 100 pages.
# K = 15

# query_engine = index.as_query_engine(
#                 similarity_top_k=K,
#                 vector_store_kwargs={
#                         "index" : "flat_index",
#                         "filter" : [[">=", "publication_date", datetime.date(2008,9,15)]],
#                         "sort_columns" : "publication_date"
#                         }
#         )

# %%
# response = query_engine.query(
#     "what did the president say about ukraine, what are the four common sense steps and how he planned to fight inflation?"
# )

# %%
# %%time

# # Using gpt-4o-mini, the 128k tokens context size can take 100 pages.
# K = 20

# query_engine = index.as_query_engine(
#                 similarity_top_k=K,
#                 vector_store_kwargs={
#                         "index" : "flat_index",
#                         "sort_columns" : "publication_date"
#                         }
#         )

# %%
# %%time

# result = query_engine.query(
#     """
#     What happened on the 15th of September 2008 ?
#     """
# )
# print(result.response)

# %% [markdown]
# ## Delete the KDB.AI Table
#
# Once finished with the table, it is best practice to drop it.

# %%
table.drop()

# %% [markdown]
# # If integrating with llamaparse
#
# https://colab.research.google.com/github/KxSystems/kdbai-samples/blob/main/LlamaParse_pdf_RAG/llamaParse_demo.ipynb

# %% [markdown]
# # metadata filtering other example:
#
# https://colab.research.google.com/github/KxSystems/kdbai-samples/blob/main/metadata_filtering/metadata_filtering_demo.ipynb#scrollTo=UkkJDOQCW7qe
